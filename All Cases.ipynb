# %%
fil7 = ['filter', 'air filter', 'filters', 'air filters']

# %%
#Case 1

# %%
fil1 = ['filter', 'air filter', 'filters', 'air filters']

# %%
att1sg = ['with [ATTRIBUTE: e.g., \"allergen defense\"]', 'with good [ATTRIBUTE: e.g., \"allergen defense\"]', 'for [ATTRIBUTE: e.g., \"allergen defense\"]', 'that [ATTRIBUTE: e.g., \"lasts\"]', 'that is [ATTRIBUTE: e.g., \"effective\"]', 'that has [ATTRIBUTE: e.g., \"quality\"]', 'that will not be [ATTRIBUTE: e.g., \"flimsy\"]', 'to clean [ATTRIBUTE: e.g., \"mold\"]', ]

# %%
for a in att1sg:
    print(att1sg.index(a), a)
# Out:
# 0 with [ATTRIBUTE: e.g., "allergen defense"]
# 1 with good [ATTRIBUTE: e.g., "allergen defense"]
# 2 for [ATTRIBUTE: e.g., "allergen defense"]
# 3 that [ATTRIBUTE: e.g., "lasts"]
# 4 that is [ATTRIBUTE: e.g., "effective"]
# 5 that has [ATTRIBUTE: e.g., "quality"]
# 6 that will not be [ATTRIBUTE: e.g., "flimsy"]
# 7 to clean [ATTRIBUTE: e.g., "mold"]

# %%
att1pl = ['with [ATTRIBUTE: e.g., \"allergen defense\"]', 'with good [ATTRIBUTE: e.g., \"allergen defense\"]', 'for [ATTRIBUTE: e.g., \"allergen defense\"]', 'that [ATTRIBUTE: e.g., \"last\"]', 'that are [ATTRIBUTE: e.g., \"effective\"]', 'that have [ATTRIBUTE: e.g., \"quality\"]', 'that will not be [ATTRIBUTE: e.g., \"flimsy\"]', 'to clean [ATTRIBUTE: e.g., \"mold\"]', ]

# %%
for a in att1pl:
    print(att1pl.index(a), a)
# Out:
# 0 with [ATTRIBUTE: e.g., "allergen defense"]
# 1 with good [ATTRIBUTE: e.g., "allergen defense"]
# 2 for [ATTRIBUTE: e.g., "allergen defense"]
# 3 that [ATTRIBUTE: e.g., "last"]
# 4 that are [ATTRIBUTE: e.g., "effective"]
# 5 that have [ATTRIBUTE: e.g., "quality"]
# 6 that will not be [ATTRIBUTE: e.g., "flimsy"]
# 7 to clean [ATTRIBUTE: e.g., "mold"]

# %%
filters = []

for f in fil1:
    for a in att1sg:
        if 'filters' in f:
            continue
        else:
            filters.append(f"{f} {a}")

for f in fil1:
    for a in att1pl:
        if 'filters' in f:
            filters.append(f"{f} {a}")
        else:
            continue

# %%
for f in filters:
    print(filters.index(f), f)
# Out:
# 0 filter with [ATTRIBUTE: e.g., "allergen defense"]
# 1 filter with good [ATTRIBUTE: e.g., "allergen defense"]
# 2 filter for [ATTRIBUTE: e.g., "allergen defense"]
# 3 filter that [ATTRIBUTE: e.g., "lasts"]
# 4 filter that is [ATTRIBUTE: e.g., "effective"]
# 5 filter that has [ATTRIBUTE: e.g., "quality"]
# 6 filter that will not be [ATTRIBUTE: e.g., "flimsy"]
# 7 filter to clean [ATTRIBUTE: e.g., "mold"]
# 8 air filter with [ATTRIBUTE: e.g., "allergen defense"]
# 9 air filter with good [ATTRIBUTE: e.g., "allergen defense"]
# 10 air filter for [ATTRIBUTE: e.g., "allergen defense"]
# 11 air filter that [ATTRIBUTE: e.g., "lasts"]
# 12 air filter that is [ATTRIBUTE: e.g., "effective"]
# 13 air filter that has [ATTRIBUTE: e.g., "quality"]
# 14 air filter that will not be [ATTRIBUTE: e.g., "flimsy"]
# 15 air filter to clean [ATTRIBUTE: e.g., "mold"]
# 16 filters with [ATTRIBUTE: e.g., "allergen defense"]
# 17 filters with good [ATTRIBUTE: e.g., "allergen defense"]
# ...

# %%
s_s = ["I\'m looking for", 'I always look for', 'I want', 'I need', 'Best', 'Good', 'Highest rated', 'Top of the line', 'Do you have']

# %%
for s in s_s:
    print(s_s.index(s), s)
# Out:
# 0 I'm looking for
# 1 I always look for
# 2 I want
# 3 I need
# 4 Best
# 5 Good
# 6 Highest rated
# 7 Top of the line
# 8 Do you have

# %%
s_s_1 = s_s[:4] + s_s[8:]

# %%
for s in s_s_1:
    print(s_s_1.index(s), s)
# Out:
# 0 I'm looking for
# 1 I always look for
# 2 I want
# 3 I need
# 4 Do you have

# %%
s_s_2 = s_s[4:8]

# %%
for s in s_s_2:
    print(s_s_2.index(s), s)
# Out:
# 0 Best
# 1 Good
# 2 Highest rated
# 3 Top of the line

# %%
list1 = []

for s in s_s_1:
    for f in filters:
        if 'filters' in f:
            list1.append(f"{s} {f}")
        else:
            if 'air' in f:
                list1.append(f"{s} an {f}")
            else:
                list1.append(f"{s} a {f}")
                
for s in s_s_2:
    for f in filters:
        list1.append(f"{s} {f}")

# %%
list_2 = []

for a in att1sg:
    if a is att1sg[0]:
        list_2.append(f"It's probably best to go {a}")
    else:
        continue

for f in fil1:
    for a in att1sg:
        if a is att1sg[0]:
            if 'filters' in f:
                list_2.append(f"{f} {a}")
            else:
                if 'air' in f:
                    list_2.append(f"An {f} {a}")
                else:
                    list_2.append(f"A {f} {a}")
        else:
            continue     
            
for f in fil1:
    for a in att1sg:
        if a is att1sg[5]:
            if 'filters' in f:
                list_2.append(f"{f} {att1pl[5]}")
            else:
                if 'air' in f:
                    list_2.append(f"An {f} {a}")
                else:
                    list_2.append(f"A {f} {a}")
        else:
            continue 
            
for f in fil1:
    for a in att1sg:
        if a is att1sg[7]:
            if 'filters' in f:
                list_2.append(f"{f} {a}")
            else:
                if 'air' in f:
                    list_2.append(f"An {f} {a}")
                else:
                    list_2.append(f"A {f} {a}")
        else:
            continue 
            
            
for f in fil1:
    for a in att1sg:
        if a is att1sg[3]:
            if 'filters' in f:
                list_2.append(f"{f} {a}")
            else:
                if 'air' in f:
                    list_2.append(f"An {f} {a}")
                else:
                    list_2.append(f"A {f} {a}")
        else:
            continue 
            
for a in att1sg:
    list_2.append(f"One {a}")
    

for f in fil1:
    list_2.append(f"The [ATTRIBUTE: e.g., \"cheap\"] {f}")

for f in fil1:
    if 'filters' in f:
        list_2.append(f"The guy that installed our air conditioning said to get [ATTRIBUTE: e.g., \"cheap\"] {f}")
    else:
        list_2.append(f"The guy that installed our air conditioning said to get a [ATTRIBUTE: e.g., \"cheap\"] {f}")
        
        
list_2.append(f"I base a lot of my decisions of [ATTRIBUTE: e.g., \"price\"]")

list_2.append(f"Ultimately, my decision-making is based on [ATTRIBUTE: e.g., \"price\"]")

for s in s_s[0:4]:
    for f in fil1:
        if 'filters' in f:
            list_2.append(f"{s} [ATTRIBUTE: e.g., \"reputable\"] {f}")
        else:
            list_2.append(f"{s} a [ATTRIBUTE: e.g., \"reputable\"] {f}")

list_2.append(f"I'm looking to filter [ATTRIBUTE: e.g., \"smoke\"] out of my house.")

# %%
for l in list_2:
    print(list_2.index(l), l)
# Out:
# 0 It's probably best to go with [ATTRIBUTE: e.g., "allergen defense"]
# 1 A filter with [ATTRIBUTE: e.g., "allergen defense"]
# 2 An air filter with [ATTRIBUTE: e.g., "allergen defense"]
# 3 filters with [ATTRIBUTE: e.g., "allergen defense"]
# 4 air filters with [ATTRIBUTE: e.g., "allergen defense"]
# 5 A filter that has [ATTRIBUTE: e.g., "quality"]
# 6 An air filter that has [ATTRIBUTE: e.g., "quality"]
# 7 filters that have [ATTRIBUTE: e.g., "quality"]
# 8 air filters that have [ATTRIBUTE: e.g., "quality"]
# 9 A filter to clean [ATTRIBUTE: e.g., "mold"]
# 10 An air filter to clean [ATTRIBUTE: e.g., "mold"]
# 11 filters to clean [ATTRIBUTE: e.g., "mold"]
# 12 air filters to clean [ATTRIBUTE: e.g., "mold"]
# 13 A filter that [ATTRIBUTE: e.g., "lasts"]
# 14 An air filter that [ATTRIBUTE: e.g., "lasts"]
# 15 filters that [ATTRIBUTE: e.g., "lasts"]
# 16 air filters that [ATTRIBUTE: e.g., "lasts"]
# 17 One with [ATTRIBUTE: e.g., "allergen defense"]
# ...

# %%
list_2com = list1[:] + list_2[:]

# %%
for l in list_2com:
    print(list_2com.index(l), l)
# Out:
# 0 I'm looking for a filter with [ATTRIBUTE: e.g., "allergen defense"]
# 1 I'm looking for a filter with good [ATTRIBUTE: e.g., "allergen defense"]
# 2 I'm looking for a filter for [ATTRIBUTE: e.g., "allergen defense"]
# 3 I'm looking for a filter that [ATTRIBUTE: e.g., "lasts"]
# 4 I'm looking for a filter that is [ATTRIBUTE: e.g., "effective"]
# 5 I'm looking for a filter that has [ATTRIBUTE: e.g., "quality"]
# 6 I'm looking for a filter that will not be [ATTRIBUTE: e.g., "flimsy"]
# 7 I'm looking for a filter to clean [ATTRIBUTE: e.g., "mold"]
# 8 I'm looking for an air filter with [ATTRIBUTE: e.g., "allergen defense"]
# 9 I'm looking for an air filter with good [ATTRIBUTE: e.g., "allergen defense"]
# 10 I'm looking for an air filter for [ATTRIBUTE: e.g., "allergen defense"]
# 11 I'm looking for an air filter that [ATTRIBUTE: e.g., "lasts"]
# 12 I'm looking for an air filter that is [ATTRIBUTE: e.g., "effective"]
# ...

# %%
case1_test = open('Case1.txt', 'w')

case1_test.write('\n'.join(sorted(list(set(list_2com)))))

case1_test.close()

# %%
#Case 2

# %%
filters2 = ['a filter', 'an air filter', 'filters', 'air filters']

# %%
s_s2 = ["I\'m looking for", "I\'m looking to purchase", 'I want', 'I need', 'I think I need', 'I am here to buy', 'I\'m here to shop for', 'I want to invest in', 'I\'m shopping for', 'Here to obtain', 'Here to pick up', ', please', 'I need to grab', 'I need to get', 'Looking to procure', 'Do you have', 'Can I buy']

# %%
for s in s_s2:
    print(s_s2.index(s), s)
# Out:
# 0 I'm looking for
# 1 I'm looking to purchase
# 2 I want
# 3 I need
# 4 I think I need
# 5 I am here to buy
# 6 I'm here to shop for
# 7 I want to invest in
# 8 I'm shopping for
# 9 Here to obtain
# 10 Here to pick up
# 11 , please
# 12 I need to grab
# 13 I need to get
# 14 Looking to procure
# 15 Do you have
# 16 Can I buy

# %%
list2 = []

for s in s_s2:
    for f in filters2:
        if s in s_s2[15:]:
            list2.append(f"{s} {f}?")
        elif s is s_s2[13]:
            list2.append(f"{s} {f} while I'm here")
        elif s is s_s2[14]:
            list2.append(f"{s} {f} for my house")
        elif s is s_s2[11]:
            list2.append(f"{f}{s}")
        else:
            list2.append(f"{s} {f}")

# %%
for l in list2:
    print(list2.index(l), l)
# Out:
# 0 I'm looking for a filter
# 1 I'm looking for an air filter
# 2 I'm looking for filters
# 3 I'm looking for air filters
# 4 I'm looking to purchase a filter
# 5 I'm looking to purchase an air filter
# 6 I'm looking to purchase filters
# 7 I'm looking to purchase air filters
# 8 I want a filter
# 9 I want an air filter
# 10 I want filters
# 11 I want air filters
# 12 I need a filter
# 13 I need an air filter
# 14 I need filters
# 15 I need air filters
# 16 I think I need a filter
# 17 I think I need an air filter
# 18 I think I need filters
# 19 I think I need air filters
# 20 I am here to buy a filter
# 21 I am here to buy an air filter
# 22 I am here to buy filters
# 23 I am here to buy air filters
# 24 I'm here to shop for a filter
# 25 I'm here to shop for an air filter
# 26 I'm here to shop for filters
# 27 I'm here to shop for air filters
# 28 I want to invest in a filter
# 29 I want to invest in an air filter
# 30 I want to invest in filters
# ...

# %%
case2_test = open('Case2.txt', 'w')

case2_test.write('\n'.join(sorted(list(set(list2)))))

case2_test.close()

# %%
#Case 3

# %%
brand = ['a [BRAND: e.g., \"3M\"] filter', 'a [BRAND: e.g., \"3M\"] air filter', '[BRAND: e.g., \"3M\"] filters', '[BRAND: e.g., \"3M\"] air filters']

# %%
s_s3 = ["I\'m looking for", "I\'m looking to purchase", 'I want', 'I need', 'I think I need', 'I am here to buy', 'I\'m here to shop for', 'I want to invest in', 'I\'m shopping for', 'Here to pick up', 'I need to grab', 'I need to get', 'Looking to purchase', 'Do you have', 'Can I buy', 'I\'d like to obtain', 'Someone told me to try', 'My mom recommended', 'I want ']

# %%
for s in s_s3:
    print(s_s3.index(s), s)
# Out:
# 0 I'm looking for
# 1 I'm looking to purchase
# 2 I want
# 3 I need
# 4 I think I need
# 5 I am here to buy
# 6 I'm here to shop for
# 7 I want to invest in
# 8 I'm shopping for
# 9 Here to pick up
# 10 I need to grab
# 11 I need to get
# 12 Looking to purchase
# 13 Do you have
# 14 Can I buy
# 15 I'd like to obtain
# 16 Someone told me to try
# 17 My mom recommended
# 18 I want

# %%
list3 = []

for s in s_s3:
    for b in brand:
        if s in s_s3[13:15]:
            list3.append(f"{s} {b}?")
        elif s is s_s3[10:12]:
            list3.append(f"{s} {b} while I'm here")
        elif s is s_s3[18]:
            for f in fil7:
                if 'filters' in f:
                    list3.append(f"{s}{f} that are [BRAND: e.g., \"3M\"]")
                else:
                    if 'air' in f:
                        list3.append(f"{s}an {f} that is [BRAND: e.g., \"3M\"]")
                    else:
                        list3.append(f"{s}a {f} that is [BRAND: e.g., \"3M\"]")
        else:
            list3.append(f"{s} {b}")

# %%
list3_2 = sorted(list(set(list3)))

# %%
for l in list3_2:
    print(list3_2.index(l), l)
# Out:
# 0 Can I buy [BRAND: e.g., "3M"] air filters?
# 1 Can I buy [BRAND: e.g., "3M"] filters?
# 2 Can I buy a [BRAND: e.g., "3M"] air filter?
# 3 Can I buy a [BRAND: e.g., "3M"] filter?
# 4 Do you have [BRAND: e.g., "3M"] air filters?
# 5 Do you have [BRAND: e.g., "3M"] filters?
# 6 Do you have a [BRAND: e.g., "3M"] air filter?
# 7 Do you have a [BRAND: e.g., "3M"] filter?
# 8 Here to pick up [BRAND: e.g., "3M"] air filters
# 9 Here to pick up [BRAND: e.g., "3M"] filters
# 10 Here to pick up a [BRAND: e.g., "3M"] air filter
# 11 Here to pick up a [BRAND: e.g., "3M"] filter
# 12 I am here to buy [BRAND: e.g., "3M"] air filters
# 13 I am here to buy [BRAND: e.g., "3M"] filters
# 14 I am here to buy a [BRAND: e.g., "3M"] air filter
# 15 I am here to buy a [BRAND: e.g., "3M"] filter
# 16 I need [BRAND: e.g., "3M"] air filters
# 17 I need [BRAND: e.g., "3M"] filters
# 18 I need a [BRAND: e.g., "3M"] air filter
# 19 I need a [BRAND: e.g., "3M"] filter
# ...

# %%
case3_test = open('Case3.txt', 'w')

case3_test.write('\n'.join(sorted(list(set(list3_2)))))

case3_test.close()

# %%
#Case 11

# %%
fil11sg = ['an air filter', 'a filter']

# %%
fil11pl = ['air filters', 'filters']

# %%
fil11com = fil11sg + fil11pl

# %%
a11pl = ['[ATTRIBUTE: e.g., \"priced"] [CRITERIA: e.g. \"less than 10 dollars"\"]', '[CRITERIA: e.g., \"less than 10\"] [ATTRIBUTE: e.g., \"dollars\"]', 'with [ATTRIBUTE: e.g., \"MERV rating"] [CRITERIA: e.g. \"below 12\"]', 'with [CRITERIA: e.g., \"at least 3\"] [ATTRIBUTE: e.g., \"stars\"]', 'that are [ATTRIBUTE: e.g., \"priced\"] [CRITERIA: e.g., \"between 10 and 20 dollars\"]', 'that have [ATTRIBUTE: e.g., \"MERV rating\"] [CRITERIA: e.g., \"higher than 10\"]', 'that have a [CRITERIA: e.g., \"at minimum 3 month\"] [ATTRIBUTE: e.g., \"replacement time\"]', 'that have [CRITERIA: e.g., \"at least a 4\"] [ATTRIBUTE: e.g., \"star rating\"]', 'that [ATTRIBUTE: e.g., \"cost\"] [CRITERIA: e.g., \"at most 15 dollars\"]', 'that I need to [ATTRIBUTE: e.g., \"change\"] [CRITERIA: e.g., \"at maximum 3 months\"]', 'with [ATTRIBUTE: e.g., \"a replacement time\"] that is [CRITERIA: e.g., \"at most 3 months\"]']

# %%
for a in a11pl:
    print(a11pl.index(a), a)
# Out:
# 0 [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g. "less than 10 dollars""]
# 1 [CRITERIA: e.g., "less than 10"] [ATTRIBUTE: e.g., "dollars"]
# 2 with [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g. "below 12"]
# 3 with [CRITERIA: e.g., "at least 3"] [ATTRIBUTE: e.g., "stars"]
# 4 that are [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "between 10 and 20 dollars"]
# 5 that have [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g., "higher than 10"]
# 6 that have a [CRITERIA: e.g., "at minimum 3 month"] [ATTRIBUTE: e.g., "replacement time"]
# 7 that have [CRITERIA: e.g., "at least a 4"] [ATTRIBUTE: e.g., "star rating"]
# 8 that [ATTRIBUTE: e.g., "cost"] [CRITERIA: e.g., "at most 15 dollars"]
# 9 that I need to [ATTRIBUTE: e.g., "change"] [CRITERIA: e.g., "at maximum 3 months"]
# 10 with [ATTRIBUTE: e.g., "a replacement time"] that is [CRITERIA: e.g., "at most 3 months"]

# %%
a11sg = ['[ATTRIBUTE: e.g., \"priced"] [CRITERIA: e.g. \"less than 10 dollars"\"]', '[CRITERIA: e.g., \"less than 10\"] [ATTRIBUTE: e.g., \"dollars\"]', 'with [ATTRIBUTE: e.g., \"MERV rating"] [CRITERIA: e.g. \"below 12\"]', 'with [CRITERIA: e.g., \"at least 3\"] [ATTRIBUTE: e.g., \"stars\"]', 'that is [ATTRIBUTE: e.g., \"priced\"] [CRITERIA: e.g., \"between 10 and 20 dollars\"]', 'that has [ATTRIBUTE: e.g., \"MERV rating\"] [CRITERIA: e.g., \"higher than 10\"]', 'that has a [CRITERIA: e.g., \"at minimum 3 month\"] [ATTRIBUTE: e.g., \"replacement time\"]', 'that has [CRITERIA: e.g., \"at least a 4\"] [ATTRIBUTE: e.g., \"star rating\"]', 'that [ATTRIBUTE: e.g., \"costs\"] [CRITERIA: e.g., \"at most 15 dollars\"]', 'that I need to [ATTRIBUTE: e.g., \"change\"] [CRITERIA: e.g., \"at maximum 3 months\"]', 'with [ATTRIBUTE: e.g., \"a replacement time\"] that is [CRITERIA: e.g., \"at most 3 months\"]']

# %%
fac1 = []

for f in fil11sg:
    for a in a11sg:
        fac1.append(f"{f} {a}")

fac2 = []

for i in fil11pl:
    for c in a11pl:
        fac2.append(f"{i} {c}")

# %%
for f in fac1:
    print(fac1.index(f), f)

for f in fac2:
    print(fac2.index(f), f)
# Out:
# 0 an air filter [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g. "less than 10 dollars""]
# 1 an air filter [CRITERIA: e.g., "less than 10"] [ATTRIBUTE: e.g., "dollars"]
# 2 an air filter with [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g. "below 12"]
# 3 an air filter with [CRITERIA: e.g., "at least 3"] [ATTRIBUTE: e.g., "stars"]
# 4 an air filter that is [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "between 10 and 20 dollars"]
# 5 an air filter that has [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g., "higher than 10"]
# 6 an air filter that has a [CRITERIA: e.g., "at minimum 3 month"] [ATTRIBUTE: e.g., "replacement time"]
# 7 an air filter that has [CRITERIA: e.g., "at least a 4"] [ATTRIBUTE: e.g., "star rating"]
# 8 an air filter that [ATTRIBUTE: e.g., "costs"] [CRITERIA: e.g., "at most 15 dollars"]
# 9 an air filter that I need to [ATTRIBUTE: e.g., "change"] [CRITERIA: e.g., "at maximum 3 months"]
# ...

# %%
fac3 = fac1 + fac2

# %%
for f in fac3:
    print(fac3.index(f), f)
# Out:
# 0 an air filter [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g. "less than 10 dollars""]
# 1 an air filter [CRITERIA: e.g., "less than 10"] [ATTRIBUTE: e.g., "dollars"]
# 2 an air filter with [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g. "below 12"]
# 3 an air filter with [CRITERIA: e.g., "at least 3"] [ATTRIBUTE: e.g., "stars"]
# 4 an air filter that is [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "between 10 and 20 dollars"]
# 5 an air filter that has [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g., "higher than 10"]
# 6 an air filter that has a [CRITERIA: e.g., "at minimum 3 month"] [ATTRIBUTE: e.g., "replacement time"]
# 7 an air filter that has [CRITERIA: e.g., "at least a 4"] [ATTRIBUTE: e.g., "star rating"]
# 8 an air filter that [ATTRIBUTE: e.g., "costs"] [CRITERIA: e.g., "at most 15 dollars"]
# 9 an air filter that I need to [ATTRIBUTE: e.g., "change"] [CRITERIA: e.g., "at maximum 3 months"]
# ...

# %%
s_s11 = ["I\'m looking for", 'I want', 'I need', 'I believe', 'I am here to purchase', 'I want to invest in', 'I\'m shopping for', 'Here to pick up', 'I need to get', 'I need to grab', 'Looking to purchase', 'Do you have', 'Someone told me to try', 'My mom suggested', 'I\'m going to go with', 'Where']

# %%
for s in s_s11:
    print(s_s11.index(s), s)
# Out:
# 0 I'm looking for
# 1 I want
# 2 I need
# 3 I believe
# 4 I am here to purchase
# 5 I want to invest in
# 6 I'm shopping for
# 7 Here to pick up
# 8 I need to get
# 9 I need to grab
# 10 Looking to purchase
# 11 Do you have
# 12 Someone told me to try
# 13 My mom suggested
# 14 I'm going to go with
# 15 Where

# %%
which11 = []

for f in fil7:
    if 'filters' in f:
        which11.append(f"Which {f} have [CRITERIA: e.g., \"at least 3\"] [ATTRIBUTES: e.g., \"stars\"]")
    else:
        which11.append(f"Which {f} has [CRITERIA: e.g., \"at least 3\"] [ATTRIBUTES: e.g., \"stars\"]")

# %%
for w in which11:
    print(which11.index(w), w)
# Out:
# 0 Which filter has [CRITERIA: e.g., "at least 3"] [ATTRIBUTES: e.g., "stars"]
# 1 Which air filter has [CRITERIA: e.g., "at least 3"] [ATTRIBUTES: e.g., "stars"]
# 2 Which filters have [CRITERIA: e.g., "at least 3"] [ATTRIBUTES: e.g., "stars"]
# 3 Which air filters have [CRITERIA: e.g., "at least 3"] [ATTRIBUTES: e.g., "stars"]

# %%
replace11 = []

for s in s_s11:
    for f in fil11com:
        if 'filters' in f and s is not s_s11[15]:
            replace11.append(f"{s} [CRITERIA: e.g., \"3 month\"] [ATTRIBUTE: e.g., \"replacement time\"] {f}")
        elif s is s_s11[15]:
            if 'filters' in f:
                replace11.append(f"{s} are [CRITERIA: e.g., \"3 month\"] [ATTRIBUTE: e.g., \"replacement time\"] {f}")
            else:
                if 'air' in f:
                    replace11.append(f"{s} is a [CRITERIA: e.g., \"3 month\"] [ATTRIBUTE: e.g., \"replacement time\"] {fil11sg[0][3:]}")
                else:
                    replace11.append(f"{s} is a [CRITERIA: e.g., \"3 month\"] [ATTRIBUTE: e.g., \"replacement time\"] {fil11sg[1][2:]}")
        else:
            if 'air' in f:
                replace11.append(f"{s} a [CRITERIA: e.g., \"3 month\"] [ATTRIBUTE: e.g., \"replacement time\"] {fil11sg[0][3:]}")
            else:
                replace11.append(f"{s} a [CRITERIA: e.g., \"3 month\"] [ATTRIBUTE: e.g., \"replacement time\"] {fil11sg[1][2:]}")

# %%
for r in replace11:
    print(replace11.index(r), r)
# Out:
# 0 I'm looking for a [CRITERIA: e.g., "3 month"] [ATTRIBUTE: e.g., "replacement time"] air filter
# 1 I'm looking for a [CRITERIA: e.g., "3 month"] [ATTRIBUTE: e.g., "replacement time"] filter
# 2 I'm looking for [CRITERIA: e.g., "3 month"] [ATTRIBUTE: e.g., "replacement time"] air filters
# 3 I'm looking for [CRITERIA: e.g., "3 month"] [ATTRIBUTE: e.g., "replacement time"] filters
# 4 I want a [CRITERIA: e.g., "3 month"] [ATTRIBUTE: e.g., "replacement time"] air filter
# 5 I want a [CRITERIA: e.g., "3 month"] [ATTRIBUTE: e.g., "replacement time"] filter
# 6 I want [CRITERIA: e.g., "3 month"] [ATTRIBUTE: e.g., "replacement time"] air filters
# 7 I want [CRITERIA: e.g., "3 month"] [ATTRIBUTE: e.g., "replacement time"] filters
# 8 I need a [CRITERIA: e.g., "3 month"] [ATTRIBUTE: e.g., "replacement time"] air filter
# 9 I need a [CRITERIA: e.g., "3 month"] [ATTRIBUTE: e.g., "replacement time"] filter
# ...

# %%
list11 = []

for s in s_s11:
    if s is s_s11[15]:
        for f in fac3:
            if 'filters' in f:
                list11.append(f'{s} are {f}')
            else:
                list11.append(f'{s} is {f}')
    elif s is s_s11[11]:
        for f in fac3:
            list11.append(f'{s} {f}')
    elif s is s_s11[8]:
        for x in fil11com:
            if 'filters' in x:
                for a in a11pl:
                    list11.append(f'{s} {x} while I\'m here {a}')
            else:
                for b in a11sg:
                    list11.append(f'{s} {x} while I\'m here {b}')
    elif s is s_s11[9]:
        for x in fil11com:
            if 'filters' in x:
                for a in a11pl:
                    list11.append(f'{s} {x} while I\'m here {a}')
            else:
                for b in a11sg:
                    list11.append(f'{s} {x} while I\'m here {b}')
    else:
        for f in fac3:
            list11.append(f'{s} {f}')

# %%
list11_2 = list11[:] + which11[:] + replace11[:]

# %%
for f in list11_2:
    print(list11_2.index(f), f)
# Out:
# 0 I'm looking for an air filter [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g. "less than 10 dollars""]
# 1 I'm looking for an air filter [CRITERIA: e.g., "less than 10"] [ATTRIBUTE: e.g., "dollars"]
# 2 I'm looking for an air filter with [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g. "below 12"]
# 3 I'm looking for an air filter with [CRITERIA: e.g., "at least 3"] [ATTRIBUTE: e.g., "stars"]
# 4 I'm looking for an air filter that is [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "between 10 and 20 dollars"]
# 5 I'm looking for an air filter that has [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g., "higher than 10"]
# 6 I'm looking for an air filter that has a [CRITERIA: e.g., "at minimum 3 month"] [ATTRIBUTE: e.g., "replacement time"]
# 7 I'm looking for an air filter that has [CRITERIA: e.g., "at least a 4"] [ATTRIBUTE: e.g., "star rating"]
# 8 I'm looking for an air filter that [ATTRIBUTE: e.g., "costs"] [CRITERIA: e.g., "at most 15 dollars"]
# ...

# %%
case11_test = open('Case11.txt', 'w')

case11_test.write('\n'.join(sorted(list(set(list11_2)))))

case11_test.close()

# %%
#Case 4

# %%
brand4 = ['a [BRAND: e.g., \"3M\"]', '[BRAND: e.g., \"3M\"]']

# %%
fil4 = ['filter', 'air filter', 'filters', 'air filters']

# %%
fb4 = []

for f in fil4:
    if f.endswith('s'):
        fb4.append(f'{brand4[1]} {f}')
    else:
        fb4.append(f'{brand4[0]} {f}')

# %%
for x in fb4:
    print(fb4.index(x), x)
# Out:
# 0 a [BRAND: e.g., "3M"] filter
# 1 a [BRAND: e.g., "3M"] air filter
# 2 [BRAND: e.g., "3M"] filters
# 3 [BRAND: e.g., "3M"] air filters

# %%
a4pl = ['[ATTRIBUTE: e.g., \"priced\"] [CRITERIA: e.g., \"at least 10 dollars\"]', '[CRITERIA: e.g., \"below 15\"] [ATTRIBUTE: e.g., \"dollars\"]', 'with [ATTRIBUTE: e.g., \"MERV\"] [CRITERIA: e.g., \"between 12 and 14\"]', 'with [CRITERIA: e.g., \"4\"] [ATTRIBUTE: e.g., \"stars\"]', 'that are [ATTRIBUTE: e.g., \"priced\"] [CRITERIA: e.g., \"between 10 and 20 dollars\"]', 'that have a [ATTRIBUTE: e.g., \"MERV rating"] [CRITERIA: e.g., \"higher than 6\"]', 'that have [CRITERIA: e.g., \"at least 4\"] [ATTRIBUTE: e.g., \"star rating\"]', 'that have [CRITERIA: e.g., \"at minimum 3 months\"] [ATTRIBUTE: e.g., \"replacement time\"]', 'that [ATTRIBUTE: e.g., \"cost\"] [CRITERIA: e.g., \"at most 15 dollars\"]', 'that I need to [ATTRIBUTE: e.g., \"change\"] [CRITERIA: e.g., \"at maximum every 3 months\"]']

# %%
for a in a4pl:
    print(a4pl.index(a), a)
# Out:
# 0 [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "at least 10 dollars"]
# 1 [CRITERIA: e.g., "below 15"] [ATTRIBUTE: e.g., "dollars"]
# 2 with [ATTRIBUTE: e.g., "MERV"] [CRITERIA: e.g., "between 12 and 14"]
# 3 with [CRITERIA: e.g., "4"] [ATTRIBUTE: e.g., "stars"]
# 4 that are [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "between 10 and 20 dollars"]
# 5 that have a [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g., "higher than 6"]
# 6 that have [CRITERIA: e.g., "at least 4"] [ATTRIBUTE: e.g., "star rating"]
# 7 that have [CRITERIA: e.g., "at minimum 3 months"] [ATTRIBUTE: e.g., "replacement time"]
# 8 that [ATTRIBUTE: e.g., "cost"] [CRITERIA: e.g., "at most 15 dollars"]
# 9 that I need to [ATTRIBUTE: e.g., "change"] [CRITERIA: e.g., "at maximum every 3 months"]

# %%
a4sg = ['[ATTRIBUTE: e.g., \"priced\"] [CRITERIA: e.g., \"at least 10 dollars\"]', '[CRITERIA: e.g., \"below 15\"] [ATTRIBUTE: e.g., \"dollars\"]', 'with [ATTRIBUTE: e.g., \"MERV\"] [CRITERIA: e.g., \"between 12 and 14\"]', 'with [CRITERIA: e.g., \"4\"] [ATTRIBUTE: e.g., \"stars\"]', 'that is [ATTRIBUTE: e.g., \"priced\"] [CRITERIA: e.g., \"between 10 and 20 dollars\"]', 'that has a [ATTRIBUTE: e.g., \"MERV rating"] [CRITERIA: e.g., \"higher than 6\"]', 'that has [CRITERIA: e.g., \"at least 4\"] [ATTRIBUTE: e.g., \"star rating\"]', 'that has [CRITERIA: e.g., \"at minimum 3 months\"] [ATTRIBUTE: e.g., \"replacement time\"]', 'that [ATTRIBUTE: e.g., \"costs\"] [CRITERIA: e.g., \"at most 15 dollars\"]', 'that I need to [ATTRIBUTE: e.g., \"change\"] [CRITERIA: e.g., \"at maximum every 3 months\"]']

# %%
for b in a4sg:
    print(a4sg.index(b), b)
# Out:
# 0 [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "at least 10 dollars"]
# 1 [CRITERIA: e.g., "below 15"] [ATTRIBUTE: e.g., "dollars"]
# 2 with [ATTRIBUTE: e.g., "MERV"] [CRITERIA: e.g., "between 12 and 14"]
# 3 with [CRITERIA: e.g., "4"] [ATTRIBUTE: e.g., "stars"]
# 4 that is [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "between 10 and 20 dollars"]
# 5 that has a [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g., "higher than 6"]
# 6 that has [CRITERIA: e.g., "at least 4"] [ATTRIBUTE: e.g., "star rating"]
# 7 that has [CRITERIA: e.g., "at minimum 3 months"] [ATTRIBUTE: e.g., "replacement time"]
# 8 that [ATTRIBUTE: e.g., "costs"] [CRITERIA: e.g., "at most 15 dollars"]
# 9 that I need to [ATTRIBUTE: e.g., "change"] [CRITERIA: e.g., "at maximum every 3 months"]

# %%
fba4 = []

for b in fb4:
    if b.endswith('s'):
        for x in a4pl:
            fba4.append(f'{b} {x}')
    else:
        for e in a4sg:
            fba4.append(f'{b} {e}')

fba4am = ['a filter [CRITERIA: e.g., \"under 10\"] [ATTRIBUTE: e.g., \"dollars\"], and I like the [BRAND: e.g., \"3M\"] brand', 'an air filter [CRITERIA: e.g., \"under 10\"] [ATTRIBUTE: e.g., \"dollars\"], and I like the [BRAND: e.g., \"3M\"] brand', 'filters [CRITERIA: e.g., \"under 10\"] [ATTRIBUTE: e.g., \"dollars\"], and I like the [BRAND: e.g., \"3M\"] brand', 'air filters [CRITERIA: e.g., \"under 10\"] [ATTRIBUTE: e.g., \"dollars\"], and I like the [BRAND: e.g., \"3M\"] brand']

fba4com = fba4[:] + fba4am[:]

# %%
for fb in fba4com:
    print(fba4com.index(fb), fb)
# Out:
# 0 a [BRAND: e.g., "3M"] filter [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "at least 10 dollars"]
# 1 a [BRAND: e.g., "3M"] filter [CRITERIA: e.g., "below 15"] [ATTRIBUTE: e.g., "dollars"]
# 2 a [BRAND: e.g., "3M"] filter with [ATTRIBUTE: e.g., "MERV"] [CRITERIA: e.g., "between 12 and 14"]
# 3 a [BRAND: e.g., "3M"] filter with [CRITERIA: e.g., "4"] [ATTRIBUTE: e.g., "stars"]
# 4 a [BRAND: e.g., "3M"] filter that is [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "between 10 and 20 dollars"]
# 5 a [BRAND: e.g., "3M"] filter that has a [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g., "higher than 6"]
# 6 a [BRAND: e.g., "3M"] filter that has [CRITERIA: e.g., "at least 4"] [ATTRIBUTE: e.g., "star rating"]
# 7 a [BRAND: e.g., "3M"] filter that has [CRITERIA: e.g., "at minimum 3 months"] [ATTRIBUTE: e.g., "replacement time"]
# 8 a [BRAND: e.g., "3M"] filter that [ATTRIBUTE: e.g., "costs"] [CRITERIA: e.g., "at most 15 dollars"]
# ...

# %%
s_s4 = ["I\'m looking for", 'I want', 'I want to invest in', 'I\'m shopping for', 'Here to pick up', 'I need to get', 'I need to grab', 'Looking to purchase', 'Do you have', 'Someone told me to try', 'Where', 'Here to shop for', 'I\'d like', 'I am here to buy']

# %%
for s in s_s4:
    print(s_s4.index(s), s)
# Out:
# 0 I'm looking for
# 1 I want
# 2 I want to invest in
# 3 I'm shopping for
# 4 Here to pick up
# 5 I need to get
# 6 I need to grab
# 7 Looking to purchase
# 8 Do you have
# 9 Someone told me to try
# 10 Where
# 11 Here to shop for
# 12 I'd like
# 13 I am here to buy

# %%
extra4 = s_s4[:8] + s_s4[11:]

# %%
for e in extra4:
    print(extra4.index(e), e)
# Out:
# 0 I'm looking for
# 1 I want
# 2 I want to invest in
# 3 I'm shopping for
# 4 Here to pick up
# 5 I need to get
# 6 I need to grab
# 7 Looking to purchase
# 8 Here to shop for
# 9 I'd like
# 10 I am here to buy

# %%
ex4full = []

for e in extra4:
    for f in fba4com:
        ex4full.append(f"{e} {f}")

# %%
for e in ex4full:
    print(ex4full.index(e), e)
# Out:
# 0 I'm looking for a [BRAND: e.g., "3M"] filter [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "at least 10 dollars"]
# 1 I'm looking for a [BRAND: e.g., "3M"] filter [CRITERIA: e.g., "below 15"] [ATTRIBUTE: e.g., "dollars"]
# 2 I'm looking for a [BRAND: e.g., "3M"] filter with [ATTRIBUTE: e.g., "MERV"] [CRITERIA: e.g., "between 12 and 14"]
# 3 I'm looking for a [BRAND: e.g., "3M"] filter with [CRITERIA: e.g., "4"] [ATTRIBUTE: e.g., "stars"]
# 4 I'm looking for a [BRAND: e.g., "3M"] filter that is [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "between 10 and 20 dollars"]
# 5 I'm looking for a [BRAND: e.g., "3M"] filter that has a [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g., "higher than 6"]
# 6 I'm looking for a [BRAND: e.g., "3M"] filter that has [CRITERIA: e.g., "at least 4"] [ATTRIBUTE: e.g., "star rating"]
# 7 I'm looking for a [BRAND: e.g., "3M"] filter that has [CRITERIA: e.g., "at minimum 3 months"] [ATTRIBUTE: e.g., "replacement time"]
# ...

# %%
wh4 = []

for f in fil4:
    if 'filters' in f:
        wh4.append(f"Which {brand4[1]} {f} have [CRITERIA: e.g., \"at least 3\"] [ATTRIBUTE: e.g., \"stars\"]")
    else:
        wh4.append(f"Which {brand4[1]} {f} has [CRITERIA: e.g., \"at least 3\"] [ATTRIBUTE: e.g., \"stars\"]")

# %%
for w in wh4:
    print(wh4.index(w), w)
# Out:
# 0 Which [BRAND: e.g., "3M"] filter has [CRITERIA: e.g., "at least 3"] [ATTRIBUTE: e.g., "stars"]
# 1 Which [BRAND: e.g., "3M"] air filter has [CRITERIA: e.g., "at least 3"] [ATTRIBUTE: e.g., "stars"]
# 2 Which [BRAND: e.g., "3M"] filters have [CRITERIA: e.g., "at least 3"] [ATTRIBUTE: e.g., "stars"]
# 3 Which [BRAND: e.g., "3M"] air filters have [CRITERIA: e.g., "at least 3"] [ATTRIBUTE: e.g., "stars"]

# %%
list4 = []

for s in s_s4:
    if s is s_s4[10]:
        for f in fba4:
            if 'filters' in f:
                list4.append(f'{s} are {f}')
            else:
                list4.append(f'{s} is {f}')
    elif s is s_s4[8]:
        for f in fba4:
            list4.append(f'{s} {f}')
    elif s is s_s4[5]:
        for x in fb4:
            if 'filters' in x:
                for a in a4pl:
                    list4.append(f'{s} {x} while I\'m here {a}')
            else:
                for b in a4sg:
                    list4.append(f'{s} {x} while I\'m here {b}')
    elif s is s_s4[6]:
        for x in fb4:
            if 'filters' in x:
                for a in a4pl:
                    list4.append(f'{s} {x} while I\'m here {a}')
            else:
                for b in a4sg:
                    list4.append(f'{s} {x} while I\'m here {b}')
    
    else:
        for f in fba4:
            list4.append(f'{s} {f}')
            
list4_2 = list4[:] + ex4full[:] + wh4[:]

# %%
list4_2_2 = sorted(list(set(list4_2)))

# %%
for l in list4_2_2:
    print(list4_2_2.index(l), l)
# Out:
# 0 Do you have [BRAND: e.g., "3M"] air filters [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "at least 10 dollars"]
# 1 Do you have [BRAND: e.g., "3M"] air filters [CRITERIA: e.g., "below 15"] [ATTRIBUTE: e.g., "dollars"]
# 2 Do you have [BRAND: e.g., "3M"] air filters that I need to [ATTRIBUTE: e.g., "change"] [CRITERIA: e.g., "at maximum every 3 months"]
# 3 Do you have [BRAND: e.g., "3M"] air filters that [ATTRIBUTE: e.g., "cost"] [CRITERIA: e.g., "at most 15 dollars"]
# 4 Do you have [BRAND: e.g., "3M"] air filters that are [ATTRIBUTE: e.g., "priced"] [CRITERIA: e.g., "between 10 and 20 dollars"]
# 5 Do you have [BRAND: e.g., "3M"] air filters that have [CRITERIA: e.g., "at least 4"] [ATTRIBUTE: e.g., "star rating"]
# 6 Do you have [BRAND: e.g., "3M"] air filters that have [CRITERIA: e.g., "at minimum 3 months"] [ATTRIBUTE: e.g., "replacement time"]
# 7 Do you have [BRAND: e.g., "3M"] air filters that have a [ATTRIBUTE: e.g., "MERV rating"] [CRITERIA: e.g., "higher than 6"]
# ...

# %%
case4_test = open('Case4.txt', 'w')

case4_test.write('\n'.join(list4_2_2))

case4_test.close()

# %%
#Case 5

# %%
brand5 = ['a [BRAND: e.g., \"3M\"]', '[BRAND: e.g., \"3M\"]']

# %%
fil5 = ['filter', 'air filter', 'filters', 'air filters']

# %%
fb5 = []

for f in fil5:
    if f.endswith('s'):
        fb5.append(f'{brand5[1]} {f}')
    else:
        fb5.append(f'{brand5[0]} {f}')

# %%
for a in fb5:
    print(fb5.index(a), a)
# Out:
# 0 a [BRAND: e.g., "3M"] filter
# 1 a [BRAND: e.g., "3M"] air filter
# 2 [BRAND: e.g., "3M"] filters
# 3 [BRAND: e.g., "3M"] air filters

# %%
a5sg = ['with [ATTRIBUTE: e.g., \"allergen defense\"]', 'good for [ATTRIBUTE: e.g., \"pets"]', 'that helps me with [ATTRIBUTE: e.g., \"dust\"]', 'with good [ATTRIBUTE: e.g., \"pleating\"]', 'to help with my [ATTRIBUTE: e.g., \"allergies\"]', 'for all the [ATTRIBUTE: e.g., \"lint\"] in our house', 'that will get a weird [ATTRIBUTE: e.g., \"odor\"] out of my apartment', 'that [ATTRIBUTE: e.g., \"performs\"] well', 'the most [ATTRIBUTE: e.g., \"effective\"]', 'that will not be [ATTRIBUTE: e.g., \"flimsy\"]', 'that won\'t cause a [ATTRIBUTE: e.g., \"stain\"] on my AC unit', 'that helps [ATTRIBUTE: e.g., \"air flow\"]', 'for my son\'s [ATTRIBUTE: e.g., \"allergies\"]', 'with exceptional [ATTRIBUTE: e.g., \"durability\"]', 'to capture all the [ATTRIBUTE: e.g., \"lint\"] in my house', 'that can help with a bad [ATTRIBUTE: e.g., \"stench\"] in my living room', 'for [ATTRIBUTE: e.g., \"mold\"] in the house']

# %%
for a in a5sg:
    print(a5sg.index(a), a)
# Out:
# 0 with [ATTRIBUTE: e.g., "allergen defense"]
# 1 good for [ATTRIBUTE: e.g., "pets"]
# 2 that helps me with [ATTRIBUTE: e.g., "dust"]
# 3 with good [ATTRIBUTE: e.g., "pleating"]
# 4 to help with my [ATTRIBUTE: e.g., "allergies"]
# 5 for all the [ATTRIBUTE: e.g., "lint"] in our house
# 6 that will get a weird [ATTRIBUTE: e.g., "odor"] out of my apartment
# 7 that [ATTRIBUTE: e.g., "performs"] well
# 8 the most [ATTRIBUTE: e.g., "effective"]
# 9 that will not be [ATTRIBUTE: e.g., "flimsy"]
# 10 that won't cause a [ATTRIBUTE: e.g., "stain"] on my AC unit
# 11 that helps [ATTRIBUTE: e.g., "air flow"]
# 12 for my son's [ATTRIBUTE: e.g., "allergies"]
# 13 with exceptional [ATTRIBUTE: e.g., "durability"]
# 14 to capture all the [ATTRIBUTE: e.g., "lint"] in my house
# 15 that can help with a bad [ATTRIBUTE: e.g., "stench"] in my living room
# 16 for [ATTRIBUTE: e.g., "mold"] in the house

# %%
a5pl = ['with [ATTRIBUTE: e.g., \"allergen defense\"]', 'good for [ATTRIBUTE: e.g., \"pets"]', 'that help me with [ATTRIBUTE: e.g., \"dust\"]', 'with good [ATTRIBUTE: e.g., \"pleating\"]', 'to help with my [ATTRIBUTE: e.g., \"allergies\"]', 'for all the [ATTRIBUTE: e.g., \"lint\"] in our house', 'that will get a weird [ATTRIBUTE: e.g., \"odor\"] out of my apartment', 'that [ATTRIBUTE: e.g., \"perform\"] well', 'the most [ATTRIBUTE: e.g., \"effective\"]', 'that will not be [ATTRIBUTE: e.g., \"flimsy\"]', 'that won\'t cause a [ATTRIBUTE: e.g., \"stain\"] on my AC unit', 'that help [ATTRIBUTE: e.g., \"air flow\"]', 'for my son\'s [ATTRIBUTE: e.g., \"allergies\"]', 'with exceptional [ATTRIBUTE: e.g., \"durability\"]', 'to capture all the [ATTRIBUTE: e.g., \"lint\"] in my house', 'that can help with a bad [ATTRIBUTE: e.g., \"stench\"] in my living room', 'for [ATTRIBUTE: e.g., \"mold\"] in the house']

# %%
for b in a5pl:
    print(a5pl.index(b), b)
# Out:
# 0 with [ATTRIBUTE: e.g., "allergen defense"]
# 1 good for [ATTRIBUTE: e.g., "pets"]
# 2 that help me with [ATTRIBUTE: e.g., "dust"]
# 3 with good [ATTRIBUTE: e.g., "pleating"]
# 4 to help with my [ATTRIBUTE: e.g., "allergies"]
# 5 for all the [ATTRIBUTE: e.g., "lint"] in our house
# 6 that will get a weird [ATTRIBUTE: e.g., "odor"] out of my apartment
# 7 that [ATTRIBUTE: e.g., "perform"] well
# 8 the most [ATTRIBUTE: e.g., "effective"]
# 9 that will not be [ATTRIBUTE: e.g., "flimsy"]
# 10 that won't cause a [ATTRIBUTE: e.g., "stain"] on my AC unit
# 11 that help [ATTRIBUTE: e.g., "air flow"]
# 12 for my son's [ATTRIBUTE: e.g., "allergies"]
# 13 with exceptional [ATTRIBUTE: e.g., "durability"]
# 14 to capture all the [ATTRIBUTE: e.g., "lint"] in my house
# 15 that can help with a bad [ATTRIBUTE: e.g., "stench"] in my living room
# 16 for [ATTRIBUTE: e.g., "mold"] in the house

# %%
fba5 = []

for b in fb5:
    if b.endswith('s'):
        for x in a5pl:
            if 'most' in x:
                fba5.append(f'{x} {b}')
            else:
                fba5.append(f'{b} {x}')
    else:
        for e in a5sg:
            if 'most' in e:
                fba5.append(f'{e} {b[2:]}')
            else:
                fba5.append(f'{b} {e}')

# %%
for f in fba5:
    print(fba5.index(f), f)
# Out:
# 0 a [BRAND: e.g., "3M"] filter with [ATTRIBUTE: e.g., "allergen defense"]
# 1 a [BRAND: e.g., "3M"] filter good for [ATTRIBUTE: e.g., "pets"]
# 2 a [BRAND: e.g., "3M"] filter that helps me with [ATTRIBUTE: e.g., "dust"]
# 3 a [BRAND: e.g., "3M"] filter with good [ATTRIBUTE: e.g., "pleating"]
# 4 a [BRAND: e.g., "3M"] filter to help with my [ATTRIBUTE: e.g., "allergies"]
# 5 a [BRAND: e.g., "3M"] filter for all the [ATTRIBUTE: e.g., "lint"] in our house
# 6 a [BRAND: e.g., "3M"] filter that will get a weird [ATTRIBUTE: e.g., "odor"] out of my apartment
# 7 a [BRAND: e.g., "3M"] filter that [ATTRIBUTE: e.g., "performs"] well
# 8 the most [ATTRIBUTE: e.g., "effective"] [BRAND: e.g., "3M"] filter
# 9 a [BRAND: e.g., "3M"] filter that will not be [ATTRIBUTE: e.g., "flimsy"]
# 10 a [BRAND: e.g., "3M"] filter that won't cause a [ATTRIBUTE: e.g., "stain"] on my AC unit
# 11 a [BRAND: e.g., "3M"] filter that helps [ATTRIBUTE: e.g., "air flow"]
# ...

# %%
s_s5 = ["I\'m looking for", 'I need', 'I want to invest in', 'Here to pick up', 'I need to get', 'I need to grab', 'Looking to purchase', 'Do you have', 'Someone told me to try', 'Can I buy', 'I\'m here to shop for', 'I\'d like to purchase', 'I like', 'Do y\'all have']

# %%
for s in s_s5:
    print(s_s5.index(s), s)
# Out:
# 0 I'm looking for
# 1 I need
# 2 I want to invest in
# 3 Here to pick up
# 4 I need to get
# 5 I need to grab
# 6 Looking to purchase
# 7 Do you have
# 8 Someone told me to try
# 9 Can I buy
# 10 I'm here to shop for
# 11 I'd like to purchase
# 12 I like
# 13 Do y'all have

# %%
s_s5mod = s_s5[0:3] + s_s5[4:6] + [x.lower() for x in s_s5[8:9]] + s_s5[10:13]

# %%
for s in s_s5mod:
    print(s_s5mod.index(s), s)
# Out:
# 0 I'm looking for
# 1 I need
# 2 I want to invest in
# 3 I need to get
# 4 I need to grab
# 5 someone told me to try
# 6 I'm here to shop for
# 7 I'd like to purchase
# 8 I like

# %%
spring5 = []

for f in fil5:
    for s in s_s5mod:
        if 'filters' in f:
            spring5.append(f"It's spring time and the [ATTRIBUTE: e.g., \"pollen\"] is bad, and {s} {brand5[1]} {f}")
        else:
            spring5.append(f"It's spring time and the [ATTRIBUTE: e.g., \"pollen\"] is bad, and {s} {brand5[0]} {f}")

# %%
for s in spring5:
    print(spring5.index(s), s)
# Out:
# 0 It's spring time and the [ATTRIBUTE: e.g., "pollen"] is bad, and I'm looking for a [BRAND: e.g., "3M"] filter
# 1 It's spring time and the [ATTRIBUTE: e.g., "pollen"] is bad, and I need a [BRAND: e.g., "3M"] filter
# 2 It's spring time and the [ATTRIBUTE: e.g., "pollen"] is bad, and I want to invest in a [BRAND: e.g., "3M"] filter
# 3 It's spring time and the [ATTRIBUTE: e.g., "pollen"] is bad, and I need to get a [BRAND: e.g., "3M"] filter
# 4 It's spring time and the [ATTRIBUTE: e.g., "pollen"] is bad, and I need to grab a [BRAND: e.g., "3M"] filter
# 5 It's spring time and the [ATTRIBUTE: e.g., "pollen"] is bad, and someone told me to try a [BRAND: e.g., "3M"] filter
# 6 It's spring time and the [ATTRIBUTE: e.g., "pollen"] is bad, and I'm here to shop for a [BRAND: e.g., "3M"] filter
# 7 It's spring time and the [ATTRIBUTE: e.g., "pollen"] is bad, and I'd like to purchase a [BRAND: e.g., "3M"] filter
# ...

# %%
hall5 = []

for f in fil5:
    for s in s_s5mod:
        if 'filters' in f:
            hall5.append(f"There's a hall in our house that {s} {brand5[1]} {f} for [ATTRIBUTE: e.g., \"mold\"] for")
        else:
            hall5.append(f"There's a hall in our house that {s} {brand5[0]} {f} for [ATTRIBUTE: e.g., \"mold\"] for")

# %%
for h in hall5:
    print(hall5.index(h), h)
# Out:
# 0 There's a hall in our house that I'm looking for a [BRAND: e.g., "3M"] filter for [ATTRIBUTE: e.g., "mold"] for
# 1 There's a hall in our house that I need a [BRAND: e.g., "3M"] filter for [ATTRIBUTE: e.g., "mold"] for
# 2 There's a hall in our house that I want to invest in a [BRAND: e.g., "3M"] filter for [ATTRIBUTE: e.g., "mold"] for
# 3 There's a hall in our house that I need to get a [BRAND: e.g., "3M"] filter for [ATTRIBUTE: e.g., "mold"] for
# 4 There's a hall in our house that I need to grab a [BRAND: e.g., "3M"] filter for [ATTRIBUTE: e.g., "mold"] for
# 5 There's a hall in our house that someone told me to try a [BRAND: e.g., "3M"] filter for [ATTRIBUTE: e.g., "mold"] for
# 6 There's a hall in our house that I'm here to shop for a [BRAND: e.g., "3M"] filter for [ATTRIBUTE: e.g., "mold"] for
# 7 There's a hall in our house that I'd like to purchase a [BRAND: e.g., "3M"] filter for [ATTRIBUTE: e.g., "mold"] for
# ...

# %%
there5 = []

for f in fil5:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            there5.append(f"There's a [ATTRIBUTE: e.g., \"smoke smell\"], so {s} {brand5[1]} {f} to help with that")
        else:
            there5.append(f"There's a [ATTRIBUTE: e.g., \"smoke smell\"], so {s} {brand5[0]} {f} to help with that")

# %%
for t in there5:
    print(there5.index(t), t)
# Out:
# 0 There's a [ATTRIBUTE: e.g., "smoke smell"], so I'm looking for a [BRAND: e.g., "3M"] filter to help with that
# 1 There's a [ATTRIBUTE: e.g., "smoke smell"], so I need a [BRAND: e.g., "3M"] filter to help with that
# 2 There's a [ATTRIBUTE: e.g., "smoke smell"], so I want to invest in a [BRAND: e.g., "3M"] filter to help with that
# 3 There's a [ATTRIBUTE: e.g., "smoke smell"], so I need to get a [BRAND: e.g., "3M"] filter to help with that
# 4 There's a [ATTRIBUTE: e.g., "smoke smell"], so I need to grab a [BRAND: e.g., "3M"] filter to help with that
# 5 There's a [ATTRIBUTE: e.g., "smoke smell"], so someone told me to try a [BRAND: e.g., "3M"] filter to help with that
# 6 There's a [ATTRIBUTE: e.g., "smoke smell"], so I'm here to shop for a [BRAND: e.g., "3M"] filter to help with that
# 7 There's a [ATTRIBUTE: e.g., "smoke smell"], so I'd like to purchase a [BRAND: e.g., "3M"] filter to help with that
# ...

# %%
list5 = []

for s in s_s5:
    if s is s_s5[7] or s is s_s5[9] or s is s_s5[13]:
        for f in fba5:
            list5.append(f'{s} {f}')
    elif s is s_s5[4] or s is s_s5[5]:
        for x in fb5:
            if 'filters' in x:
                for a in a5pl:
                    if 'most' in a:
                        list5.append(f'{s} {a} {x} while I\'m here')
                    else:
                        list5.append(f'{s} {x} while I\'m here {a}')
            else:
                for b in a5sg:
                    if 'most' in b:
                        list5.append(f'{s} {b} {x[2:]} while I\'m here')
                    else:
                        list5.append(f'{s} {x} while I\'m here {b}')
    else:
        for f in fba5:
            list5.append(f'{s} {f}')

# %%
list5_2 = list5[:] + spring5[:] + hall5[:] + there5[:]

# %%
for l in list5_2:
    print(list5_2.index(l), l)
# Out:
# 0 I'm looking for a [BRAND: e.g., "3M"] filter with [ATTRIBUTE: e.g., "allergen defense"]
# 1 I'm looking for a [BRAND: e.g., "3M"] filter good for [ATTRIBUTE: e.g., "pets"]
# 2 I'm looking for a [BRAND: e.g., "3M"] filter that helps me with [ATTRIBUTE: e.g., "dust"]
# 3 I'm looking for a [BRAND: e.g., "3M"] filter with good [ATTRIBUTE: e.g., "pleating"]
# 4 I'm looking for a [BRAND: e.g., "3M"] filter to help with my [ATTRIBUTE: e.g., "allergies"]
# 5 I'm looking for a [BRAND: e.g., "3M"] filter for all the [ATTRIBUTE: e.g., "lint"] in our house
# 6 I'm looking for a [BRAND: e.g., "3M"] filter that will get a weird [ATTRIBUTE: e.g., "odor"] out of my apartment
# 7 I'm looking for a [BRAND: e.g., "3M"] filter that [ATTRIBUTE: e.g., "performs"] well
# 8 I'm looking for the most [ATTRIBUTE: e.g., "effective"] [BRAND: e.g., "3M"] filter
# 9 I'm looking for a [BRAND: e.g., "3M"] filter that will not be [ATTRIBUTE: e.g., "flimsy"]
# ...

# %%
case5_test = open('Case5.txt', 'w')

case5_test.write('\n'.join(sorted(list(set(list5_2)))))

case5_test.close()

# %%
#Case 6

# %%
brand6 = ['a [BRAND: e.g., \"3M\"]', '[BRAND: e.g., \"3M\"]']

# %%
fil6 = ['filter', 'air filter', 'filters', 'air filters']

# %%
fb6 = []

for f in fil6:
    if f.endswith('s'):
        fb6.append(f'{brand6[1]} {f}')
    else:
        fb6.append(f'{brand6[0]} {f}')

# %%
for f in fb6:
    print(fb6.index(f), f)
# Out:
# 0 a [BRAND: e.g., "3M"] filter
# 1 a [BRAND: e.g., "3M"] air filter
# 2 [BRAND: e.g., "3M"] filters
# 3 [BRAND: e.g., "3M"] air filters

# %%
a6sg = ['with good [ATTRIBUTE: e.g., \"customer reviews\"]', 'that [ATTRIBUTE: e.g., \"lasts\"]', 'the most [ATTRIBUTE: e.g., \"economical\"]', 'with exceptional [ATTRIBUTE: e.g., \"efficiency ratings\"]', 'that I don\'t have to [ATTRIBUTE: e.g., \"change\"] that often', 'that will [ATTRIBUTE: e.g., \"last\"] me a long time', 'with good [ATTRIBUTE: e.g., \"replacement time\"]']

# %%
for a in a6sg:
    print(a6sg.index(a), a)
# Out:
# 0 with good [ATTRIBUTE: e.g., "customer reviews"]
# 1 that [ATTRIBUTE: e.g., "lasts"]
# 2 the most [ATTRIBUTE: e.g., "economical"]
# 3 with exceptional [ATTRIBUTE: e.g., "efficiency ratings"]
# 4 that I don't have to [ATTRIBUTE: e.g., "change"] that often
# 5 that will [ATTRIBUTE: e.g., "last"] me a long time
# 6 with good [ATTRIBUTE: e.g., "replacement time"]

# %%
fba6 = []

for f in fb6:
    for a in a6sg:
        if a is a6sg[2]:
            if 'filters' in f:
                fba6.append(f"{a} {f}")
            else:
                fba6.append(f"{a} {f[2:]}")
        else:
            fba6.append(f"{f} {a}")

# %%
for f in fba6:
    print(fba6.index(f), f)
# Out:
# 0 a [BRAND: e.g., "3M"] filter with good [ATTRIBUTE: e.g., "customer reviews"]
# 1 a [BRAND: e.g., "3M"] filter that [ATTRIBUTE: e.g., "lasts"]
# 2 the most [ATTRIBUTE: e.g., "economical"] [BRAND: e.g., "3M"] filter
# 3 a [BRAND: e.g., "3M"] filter with exceptional [ATTRIBUTE: e.g., "efficiency ratings"]
# 4 a [BRAND: e.g., "3M"] filter that I don't have to [ATTRIBUTE: e.g., "change"] that often
# 5 a [BRAND: e.g., "3M"] filter that will [ATTRIBUTE: e.g., "last"] me a long time
# 6 a [BRAND: e.g., "3M"] filter with good [ATTRIBUTE: e.g., "replacement time"]
# 7 a [BRAND: e.g., "3M"] air filter with good [ATTRIBUTE: e.g., "customer reviews"]
# 8 a [BRAND: e.g., "3M"] air filter that [ATTRIBUTE: e.g., "lasts"]
# 9 the most [ATTRIBUTE: e.g., "economical"] [BRAND: e.g., "3M"] air filter
# 10 a [BRAND: e.g., "3M"] air filter with exceptional [ATTRIBUTE: e.g., "efficiency ratings"]
# 11 a [BRAND: e.g., "3M"] air filter that I don't have to [ATTRIBUTE: e.g., "change"] that often
# ...

# %%
cheap6 = []

for f in fil7:
    cheap6.append(f"the [ATTRIBUTE: e.g., \"cheapest\"] {brand6[1]} {f} you got")

# %%
for c in cheap6:
    print(cheap6.index(c), c)
# Out:
# 0 the [ATTRIBUTE: e.g., "cheapest"] [BRAND: e.g., "3M"] filter you got
# 1 the [ATTRIBUTE: e.g., "cheapest"] [BRAND: e.g., "3M"] air filter you got
# 2 the [ATTRIBUTE: e.g., "cheapest"] [BRAND: e.g., "3M"] filters you got
# 3 the [ATTRIBUTE: e.g., "cheapest"] [BRAND: e.g., "3M"] air filters you got

# %%
that6 = []

for f in fil7:
    if 'filters' in f:
        that6.append(f"{brand6[1]} {f} that are [ATTRIBUTE: e.g., \"cheap\"]")
    else:
        that6.append(f"{brand6[0]} {f} that is [ATTRIBUTE: e.g., \"cheap\"]")

# %%
for t in that6:
    print(that6.index(t), t)
# Out:
# 0 a [BRAND: e.g., "3M"] filter that is [ATTRIBUTE: e.g., "cheap"]
# 1 a [BRAND: e.g., "3M"] air filter that is [ATTRIBUTE: e.g., "cheap"]
# 2 [BRAND: e.g., "3M"] filters that are [ATTRIBUTE: e.g., "cheap"]
# 3 [BRAND: e.g., "3M"] air filters that are [ATTRIBUTE: e.g., "cheap"]

# %%
good6 = []

for f in fil7:
    if 'filters' in f:
        good6.append(f"good [ATTRIBUTE: e.g., \"priced\"] {brand6[1]} {f}")
    else:
        good6.append(f"a good [ATTRIBUTE: e.g., \"priced\"] {brand6[1]} {f}")

# %%
for g in good6:
    print(good6.index(g), g)
# Out:
# 0 a good [ATTRIBUTE: e.g., "priced"] [BRAND: e.g., "3M"] filter
# 1 a good [ATTRIBUTE: e.g., "priced"] [BRAND: e.g., "3M"] air filter
# 2 good [ATTRIBUTE: e.g., "priced"] [BRAND: e.g., "3M"] filters
# 3 good [ATTRIBUTE: e.g., "priced"] [BRAND: e.g., "3M"] air filters

# %%
do6 = []

for f in fil7:
    if 'filters' in f:
        do6.append(f"[ATTRIBUTE: e.g., \"reputable\"] [BRAND: e.g., \"Honeywell\"] {f} for the house")
    else:
        do6.append(f"a [ATTRIBUTE: e.g., \"reputable\"] [BRAND: e.g., \"Honeywell\"] {f} for the house")

# %%
for d in do6:
    print(do6.index(d), d)
# Out:
# 0 a [ATTRIBUTE: e.g., "reputable"] [BRAND: e.g., "Honeywell"] filter for the house
# 1 a [ATTRIBUTE: e.g., "reputable"] [BRAND: e.g., "Honeywell"] air filter for the house
# 2 [ATTRIBUTE: e.g., "reputable"] [BRAND: e.g., "Honeywell"] filters for the house
# 3 [ATTRIBUTE: e.g., "reputable"] [BRAND: e.g., "Honeywell"] air filters for the house

# %%
fba6com = fba6[:] + cheap6[:] + that6[:] + good6[:] + do6[:]

# %%
for f in fba6com:
    print(fba6com.index(f), f)
# Out:
# 0 a [BRAND: e.g., "3M"] filter with good [ATTRIBUTE: e.g., "customer reviews"]
# 1 a [BRAND: e.g., "3M"] filter that [ATTRIBUTE: e.g., "lasts"]
# 2 the most [ATTRIBUTE: e.g., "economical"] [BRAND: e.g., "3M"] filter
# 3 a [BRAND: e.g., "3M"] filter with exceptional [ATTRIBUTE: e.g., "efficiency ratings"]
# 4 a [BRAND: e.g., "3M"] filter that I don't have to [ATTRIBUTE: e.g., "change"] that often
# 5 a [BRAND: e.g., "3M"] filter that will [ATTRIBUTE: e.g., "last"] me a long time
# 6 a [BRAND: e.g., "3M"] filter with good [ATTRIBUTE: e.g., "replacement time"]
# 7 a [BRAND: e.g., "3M"] air filter with good [ATTRIBUTE: e.g., "customer reviews"]
# 8 a [BRAND: e.g., "3M"] air filter that [ATTRIBUTE: e.g., "lasts"]
# 9 the most [ATTRIBUTE: e.g., "economical"] [BRAND: e.g., "3M"] air filter
# 10 a [BRAND: e.g., "3M"] air filter with exceptional [ATTRIBUTE: e.g., "efficiency ratings"]
# 11 a [BRAND: e.g., "3M"] air filter that I don't have to [ATTRIBUTE: e.g., "change"] that often
# ...

# %%
s_s6 = ['I need', 'I want to invest in', 'Here to pick up', 'I need to grab', 'Looking to purchase', 'Do you have', 'Someone told me to try', 'Can I buy', 'I\'m in the market for', 'I like', 'Do y\'all have', 'I think I need']

# %%
for s in s_s6:
    print(s_s6.index(s), s)
# Out:
# 0 I need
# 1 I want to invest in
# 2 Here to pick up
# 3 I need to grab
# 4 Looking to purchase
# 5 Do you have
# 6 Someone told me to try
# 7 Can I buy
# 8 I'm in the market for
# 9 I like
# 10 Do y'all have
# 11 I think I need

# %%
anything6 = []

for f in fil7:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            anything6.append(f"{s} {brand6[1]} {f}, but I don't want anything too [ATTRIBUTE: e.g., \"expensive\"]")
        else:
            anything6.append(f"{s} {brand6[0]} {f}, but I don't want anything too [ATTRIBUTE: e.g., \"expensive\"]")

# %%
for a in anything6:
    print(anything6.index(a), a)
# Out:
# 0 I'm looking for a [BRAND: e.g., "3M"] filter, but I don't want anything too [ATTRIBUTE: e.g., "expensive"]
# 1 I need a [BRAND: e.g., "3M"] filter, but I don't want anything too [ATTRIBUTE: e.g., "expensive"]
# 2 I want to invest in a [BRAND: e.g., "3M"] filter, but I don't want anything too [ATTRIBUTE: e.g., "expensive"]
# 3 I need to get a [BRAND: e.g., "3M"] filter, but I don't want anything too [ATTRIBUTE: e.g., "expensive"]
# 4 I need to grab a [BRAND: e.g., "3M"] filter, but I don't want anything too [ATTRIBUTE: e.g., "expensive"]
# 5 someone told me to try a [BRAND: e.g., "3M"] filter, but I don't want anything too [ATTRIBUTE: e.g., "expensive"]
# 6 I'm here to shop for a [BRAND: e.g., "3M"] filter, but I don't want anything too [ATTRIBUTE: e.g., "expensive"]
# 7 I'd like to purchase a [BRAND: e.g., "3M"] filter, but I don't want anything too [ATTRIBUTE: e.g., "expensive"]
# ...

# %%
interest6 = []

for f in fil7:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            interest6.append(f"I'm on a [ATTRIBUTE: e.g., \"budget\"], and {s} {brand6[1]} {f}")
        else:
            interest6.append(f"I'm on a [ATTRIBUTE: e.g., \"budget\"], and {s} {brand6[0]} {f}")

# %%
for a in interest6:
    print(interest6.index(a), a)
# Out:
# 0 I'm on a [ATTRIBUTE: e.g., "budget"], and I'm looking for a [BRAND: e.g., "3M"] filter
# 1 I'm on a [ATTRIBUTE: e.g., "budget"], and I need a [BRAND: e.g., "3M"] filter
# 2 I'm on a [ATTRIBUTE: e.g., "budget"], and I want to invest in a [BRAND: e.g., "3M"] filter
# 3 I'm on a [ATTRIBUTE: e.g., "budget"], and I need to get a [BRAND: e.g., "3M"] filter
# 4 I'm on a [ATTRIBUTE: e.g., "budget"], and I need to grab a [BRAND: e.g., "3M"] filter
# 5 I'm on a [ATTRIBUTE: e.g., "budget"], and someone told me to try a [BRAND: e.g., "3M"] filter
# 6 I'm on a [ATTRIBUTE: e.g., "budget"], and I'm here to shop for a [BRAND: e.g., "3M"] filter
# 7 I'm on a [ATTRIBUTE: e.g., "budget"], and I'd like to purchase a [BRAND: e.g., "3M"] filter
# 8 I'm on a [ATTRIBUTE: e.g., "budget"], and I'm looking for a [BRAND: e.g., "3M"] air filter
# 9 I'm on a [ATTRIBUTE: e.g., "budget"], and I need a [BRAND: e.g., "3M"] air filter
# ...

# %%
dont6 = []

for f in fil7:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            dont6.append(f"{s} {brand6[1]} {f}, but I don't want to  [ATTRIBUTE: e.g., \"pay\"] too much if that's okay")
        else:
            dont6.append(f"{s} {brand6[0]} {f}, but I don't want to  [ATTRIBUTE: e.g., \"pay\"] too much if that's okay")

# %%
for a in dont6:
    print(dont6.index(a), a)
# Out:
# 0 I'm looking for a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "pay"] too much if that's okay
# 1 I need a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "pay"] too much if that's okay
# 2 I want to invest in a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "pay"] too much if that's okay
# 3 I need to get a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "pay"] too much if that's okay
# 4 I need to grab a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "pay"] too much if that's okay
# 5 someone told me to try a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "pay"] too much if that's okay
# 6 I'm here to shop for a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "pay"] too much if that's okay
# 7 I'd like to purchase a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "pay"] too much if that's okay
# ...

# %%
price6 = []

for s in s_s5mod[:8]:
    price6.append(f"{s} the {brand6[1]}, and  [ATTRIBUTE: e.g., \"price\"] is the first thing I look at")

# %%
for a in price6:
    print(price6.index(a), a)
# Out:
# 0 I'm looking for the [BRAND: e.g., "3M"], and  [ATTRIBUTE: e.g., "price"] is the first thing I look at
# 1 I need the [BRAND: e.g., "3M"], and  [ATTRIBUTE: e.g., "price"] is the first thing I look at
# 2 I want to invest in the [BRAND: e.g., "3M"], and  [ATTRIBUTE: e.g., "price"] is the first thing I look at
# 3 I need to get the [BRAND: e.g., "3M"], and  [ATTRIBUTE: e.g., "price"] is the first thing I look at
# 4 I need to grab the [BRAND: e.g., "3M"], and  [ATTRIBUTE: e.g., "price"] is the first thing I look at
# 5 someone told me to try the [BRAND: e.g., "3M"], and  [ATTRIBUTE: e.g., "price"] is the first thing I look at
# 6 I'm here to shop for the [BRAND: e.g., "3M"], and  [ATTRIBUTE: e.g., "price"] is the first thing I look at
# 7 I'd like to purchase the [BRAND: e.g., "3M"], and  [ATTRIBUTE: e.g., "price"] is the first thing I look at

# %%
replace6 = []

for f in fil7:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            replace6.append(f"{s} {brand6[1]} {f}, but I don't want to  [ATTRIBUTE: e.g., \"replace\"] them all the time")
        else:
            replace6.append(f"{s} {brand6[0]} {f}, but I don't want to  [ATTRIBUTE: e.g., \"replace\"] it all the time")

# %%
for a in replace6:
    print(replace6.index(a), a)
# Out:
# 0 I'm looking for a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "replace"] it all the time
# 1 I need a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "replace"] it all the time
# 2 I want to invest in a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "replace"] it all the time
# 3 I need to get a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "replace"] it all the time
# 4 I need to grab a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "replace"] it all the time
# 5 someone told me to try a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "replace"] it all the time
# 6 I'm here to shop for a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "replace"] it all the time
# 7 I'd like to purchase a [BRAND: e.g., "3M"] filter, but I don't want to  [ATTRIBUTE: e.g., "replace"] it all the time
# ...

# %%
where6 = ["Where's the best [ATTRIBUTE: e.g., \"priced\"] [BRAND: e.g., \"Honeywell\"] you have"]

# %%
list6 = []

for s in s_s6:
    if s is s_s6[5] or s is s_s6[7] or s is s_s6[10]:
        for f in fba6com:
            list6.append(f'{s} {f}')
    elif s is s_s6[3]:
        for x in fb6:
            for b in a6sg:
                if 'most' in b:
                    if 'filters' in x:
                        list6.append(f'{s} {b} {x} while I\'m here')
                    else:
                         list6.append(f'{s} {b} {x[2:]} while I\'m here')
                else:
                    list6.append(f'{s} {x} while I\'m here {b}')
    else:
        for f in fba6com:
            list6.append(f'{s} {f}')

# %%
list6_2 = list6[:] + anything6[:] + interest6[:] + dont6[:] + price6[:] + replace6[:] + where6[:]

# %%
for l in list6_2:
    print(list6_2.index(l), l)
# Out:
# 0 I need a [BRAND: e.g., "3M"] filter with good [ATTRIBUTE: e.g., "customer reviews"]
# 1 I need a [BRAND: e.g., "3M"] filter that [ATTRIBUTE: e.g., "lasts"]
# 2 I need the most [ATTRIBUTE: e.g., "economical"] [BRAND: e.g., "3M"] filter
# 3 I need a [BRAND: e.g., "3M"] filter with exceptional [ATTRIBUTE: e.g., "efficiency ratings"]
# 4 I need a [BRAND: e.g., "3M"] filter that I don't have to [ATTRIBUTE: e.g., "change"] that often
# 5 I need a [BRAND: e.g., "3M"] filter that will [ATTRIBUTE: e.g., "last"] me a long time
# 6 I need a [BRAND: e.g., "3M"] filter with good [ATTRIBUTE: e.g., "replacement time"]
# 7 I need a [BRAND: e.g., "3M"] air filter with good [ATTRIBUTE: e.g., "customer reviews"]
# 8 I need a [BRAND: e.g., "3M"] air filter that [ATTRIBUTE: e.g., "lasts"]
# 9 I need the most [ATTRIBUTE: e.g., "economical"] [BRAND: e.g., "3M"] air filter
# 10 I need a [BRAND: e.g., "3M"] air filter with exceptional [ATTRIBUTE: e.g., "efficiency ratings"]
# ...

# %%
case6_test = open('Case6.txt', 'w')

case6_test.write('\n'.join(sorted(list(set(list6_2)))))

case6_test.close()

# %%
#Case 7

# %%
#fil7 = ['filter', 'air filter', 'filters', 'air filters']

# %%
a7sg = ['with the best [ATTRIBUTE: e.g., \"MERV rating\"]', 'the most [ATTRIBUTE: e.g., \"superior\"]', 'that has [ATTRIBUTE: e.g., \"allergen defense\"] and [ATTRIBUTE: e.g., \"pet dander\"] filtering', 'that is not [ATTRIBUTE: e.g., \"flimsy\"] and catches the [ATTRIBUTE: e.g., \"clumps\"] and [ATTRIBUTE: e.g., \"dust\"] in the air', 'for [ATTRIBUTE: e.g., \"dust\"]', 'for [ATTRIBUTE: e.g., \"smoke odor\"] problems', 'with lots of [ATTRIBUTE: e.g., \"pleating\"] that catches [ATTRIBUTE: e.g., \"pet hair\"]', 'that has a good [ATTRIBUTE: e.g., \"customer rating\"], it\'s not too [ATTRIBUTE: e.g., \"expensive\"] and seems [ATTRIBUTE: e.g., \"durable\"]', 'something to catch the [ATTRIBUTE: e.g., \"particulates\"] in the air but isn\'t going to [ATTRIBUTE: e.g., \"cost\"] much', 'that isn\'t [ATTRIBUTE: e.g., \"generic looking\"]', 'that gets [ATTRIBUTE: e.g., \"lint\"] out of the air', 'that [ATTRIBUTE: e.g., \"looks good\"] and has a [ATTRIBUTE: e.g., \"good evaluation\"] but is [ATTRIBUTE: e.g., \"cheap\"], please', 'with a good [ATTRIBUTE: e.g., \"rating\"] that I don\'t have to [ATTRIBUTE: e.g., \"replace\"] too often', 'to get a [ATTRIBUTE: e.g., \"smoke smell\"] out of the air', 'for [ATTRIBUTE: e.g., \"fungus\"], [ATTRIBUTE: e.g., \"mold\"], [ATTRIBUTE: e.g., \"spores\"] and has good [ATTRIBUTE: e.g., \"material\"]']

# %%
for a in a7sg:
    print(a7sg.index(a), a)
# Out:
# 0 with the best [ATTRIBUTE: e.g., "MERV rating"]
# 1 the most [ATTRIBUTE: e.g., "superior"]
# 2 that has [ATTRIBUTE: e.g., "allergen defense"] and [ATTRIBUTE: e.g., "pet dander"] filtering
# 3 that is not [ATTRIBUTE: e.g., "flimsy"] and catches the [ATTRIBUTE: e.g., "clumps"] and [ATTRIBUTE: e.g., "dust"] in the air
# 4 for [ATTRIBUTE: e.g., "dust"]
# 5 for [ATTRIBUTE: e.g., "smoke odor"] problems
# 6 with lots of [ATTRIBUTE: e.g., "pleating"] that catches [ATTRIBUTE: e.g., "pet hair"]
# 7 that has a good [ATTRIBUTE: e.g., "customer rating"], it's not too [ATTRIBUTE: e.g., "expensive"] and seems [ATTRIBUTE: e.g., "durable"]
# 8 something to catch the [ATTRIBUTE: e.g., "particulates"] in the air but isn't going to [ATTRIBUTE: e.g., "cost"] much
# 9 that isn't [ATTRIBUTE: e.g., "generic looking"]
# 10 that gets [ATTRIBUTE: e.g., "lint"] out of the air
# 11 that [ATTRIBUTE: e.g., "looks good"] and has a [ATTRIBUTE: e.g., "good evaluation"] but is [ATTRIBUTE: e.g., "cheap"], please
# ...

# %%
a7pl = ['with the best [ATTRIBUTE: e.g., \"MERV rating\"]', 'the most [ATTRIBUTE: e.g., \"superior\"]', 'that have [ATTRIBUTE: e.g., \"allergen defense\"] and [ATTRIBUTE: e.g., \"pet dander\"] filtering', 'that are not [ATTRIBUTE: e.g., \"flimsy\"] and catch the [ATTRIBUTE: e.g., \"clumps\"] and [ATTRIBUTE: e.g., \"dust\"] in the air', 'for [ATTRIBUTE: e.g., \"dust\"]', 'for [ATTRIBUTE: e.g., \"smoke odor\"] problems', 'with lots of [ATTRIBUTE: e.g., \"pleating\"] that catch [ATTRIBUTE: e.g., \"pet hair\"]', 'that have a good [ATTRIBUTE: e.g., \"customer rating\"], they\'re not too [ATTRIBUTE: e.g., \"expensive\"] and seem [ATTRIBUTE: e.g., \"durable\"]', 'something to catch the [ATTRIBUTE: e.g., \"particulates\"] in the air but aren\'t going to [ATTRIBUTE: e.g., \"cost\"] much', 'that aren\'t [ATTRIBUTE: e.g., \"generic looking\"]', 'that get [ATTRIBUTE: e.g., \"lint\"] out of the air', 'that [ATTRIBUTE: e.g., \"look good\"] and have a [ATTRIBUTE: e.g., \"good evaluation\"] but are [ATTRIBUTE: e.g., \"cheap\"], please', 'with a good [ATTRIBUTE: e.g., \"rating\"] that I don\'t have to [ATTRIBUTE: e.g., \"replace\"] too often', 'to get a [ATTRIBUTE: e.g., \"smoke smell\"] out of the air', 'for [ATTRIBUTE: e.g., \"fungus\"], [ATTRIBUTE: e.g., \"mold\"], [ATTRIBUTE: e.g., \"spores\"] and have good [ATTRIBUTE: e.g., \"material\"]']

# %%
for b in a7pl:
    print(a7pl.index(b), b)
# Out:
# 0 with the best [ATTRIBUTE: e.g., "MERV rating"]
# 1 the most [ATTRIBUTE: e.g., "superior"]
# 2 that have [ATTRIBUTE: e.g., "allergen defense"] and [ATTRIBUTE: e.g., "pet dander"] filtering
# 3 that are not [ATTRIBUTE: e.g., "flimsy"] and catch the [ATTRIBUTE: e.g., "clumps"] and [ATTRIBUTE: e.g., "dust"] in the air
# 4 for [ATTRIBUTE: e.g., "dust"]
# 5 for [ATTRIBUTE: e.g., "smoke odor"] problems
# 6 with lots of [ATTRIBUTE: e.g., "pleating"] that catch [ATTRIBUTE: e.g., "pet hair"]
# 7 that have a good [ATTRIBUTE: e.g., "customer rating"], they're not too [ATTRIBUTE: e.g., "expensive"] and seem [ATTRIBUTE: e.g., "durable"]
# 8 something to catch the [ATTRIBUTE: e.g., "particulates"] in the air but aren't going to [ATTRIBUTE: e.g., "cost"] much
# 9 that aren't [ATTRIBUTE: e.g., "generic looking"]
# 10 that get [ATTRIBUTE: e.g., "lint"] out of the air
# 11 that [ATTRIBUTE: e.g., "look good"] and have a [ATTRIBUTE: e.g., "good evaluation"] but are [ATTRIBUTE: e.g., "cheap"], please
# ...

# %%
fa7 = []

for f in fil7:
    if 'filters' in f:
        for a in a7pl:
            if 'best' in a:
                fa7.append(f"the {f} {a}")
            elif 'for' in a:
                fa7.append(f"[ATTRIBUTE: e.g., \"inexpensive\"] {f} {a}")
            elif 'that are\'t [ATTRIBUTE: e.g., \"generic looking\"]' in a:
                fa7.append(f"[ATTRIBUTE: e.g., \"good\"] {f} {a}")
            elif 'that get [ATTRIBUTE: e.g., \"lint\"] out of the air' in a:
                fa7.append(f"[ATTRIBUTE: e.g., \"sturdy\"], [ATTRIBUTE: e.g., \"cheap\"] {f} {a}")
            elif 'and have good [ATTRIBUTE: e.g., \"material\"]' in a:
                fa7.append(f"the [ATTRIBUTE: e.g., \"cheapest\"] {f} {a}")
            elif 'to get a [ATTRIBUTE: e.g., \"smoke smell\"] out of the air' in a:
                fa7.append(f"[ATTRIBUTE: e.g., \"reputable\"] {f} {a}")
            elif 'the most' in a:
                for a in a7pl:
                    if a is not a7pl[1]:
                        fa7.append(f"{a7pl[1]} {f} {a}")
            else:
                fa7.append(f"{f} {a}")
    else:
        for b in a7sg:
            if 'best' in b:
                fa7.append(f"the {f} {b}")
            elif 'for' in b:
                fa7.append(f"a [ATTRIBUTE: e.g., \"inexpensive\"] {f} {b}")
            elif 'that isn\'t [ATTRIBUTE: e.g., \"generic looking\"]' in b:
                fa7.append(f"a [ATTRIBUTE: e.g., \"good\"] {f} {b}")
            elif 'that gets [ATTRIBUTE: e.g., \"lint\"] out of the air' in b:
                fa7.append(f"a [ATTRIBUTE: e.g., \"sturdy\"], [ATTRIBUTE: e.g., \"cheap\"] {f} {b}")
            elif 'and has good [ATTRIBUTE: e.g., \"material\"]' in b:
                fa7.append(f"the [ATTRIBUTE: e.g., \"cheapest\"] {f} {b}")
            elif 'to get a [ATTRIBUTE: e.g., \"smoke smell\"] out of the air' in b:
                fa7.append(f"a [ATTRIBUTE: e.g., \"reputable\"] {f} {b}")
            elif 'the most' in b:
                for d in a7sg:
                    if d is a7sg[1]:
                        continue
                    if d is a7sg[8]:
                        continue
                    else:
                        fa7.append(f"{a7sg[1]} {f} {d}")
            elif 'something' in b:
                fa7.append(f"{b}")
            else:
                if 'air filter' in f:
                    fa7.append(f"an {f} {b}")
                else:
                    fa7.append(f"a {f} {b}")

# %%
for f in fa7:
    print(fa7.index(f), f)
# Out:
# 0 the filter with the best [ATTRIBUTE: e.g., "MERV rating"]
# 1 the most [ATTRIBUTE: e.g., "superior"] filter with the best [ATTRIBUTE: e.g., "MERV rating"]
# 2 the most [ATTRIBUTE: e.g., "superior"] filter that has [ATTRIBUTE: e.g., "allergen defense"] and [ATTRIBUTE: e.g., "pet dander"] filtering
# 3 the most [ATTRIBUTE: e.g., "superior"] filter that is not [ATTRIBUTE: e.g., "flimsy"] and catches the [ATTRIBUTE: e.g., "clumps"] and [ATTRIBUTE: e.g., "dust"] in the air
# 4 the most [ATTRIBUTE: e.g., "superior"] filter for [ATTRIBUTE: e.g., "dust"]
# 5 the most [ATTRIBUTE: e.g., "superior"] filter for [ATTRIBUTE: e.g., "smoke odor"] problems
# 6 the most [ATTRIBUTE: e.g., "superior"] filter with lots of [ATTRIBUTE: e.g., "pleating"] that catches [ATTRIBUTE: e.g., "pet hair"]
# 7 the most [ATTRIBUTE: e.g., "superior"] filter that has a good [ATTRIBUTE: e.g., "customer rating"], it's not too [ATTRIBUTE: e.g., "expensive"] and seems [ATTRIBUTE: e.g., "durable"]
# ...

# %%
s_s7 = ['I need', 'I want', 'Do you have', 'I don\'t care what brand it is, but I need', 'I like', 'Can you show me', 'I\'m looking for', 'Do y\'all have', 'I\'d like']

# %%
for s in s_s7:
    print(s_s7.index(s), s)
# Out:
# 0 I need
# 1 I want
# 2 Do you have
# 3 I don't care what brand it is, but I need
# 4 I like
# 5 Can you show me
# 6 I'm looking for
# 7 Do y'all have
# 8 I'd like

# %%
apparent7 = []

for f in fil7:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            apparent7.append(f"Apparently we have [ATTRIBUTE: e.g., \"mold\"] and [ATTRIBUTE: e.g., \"spores\"] in the house, so {s} {f} for that")
        else:
            if 'air filter' in f:
                apparent7.append(f"Apparently we have [ATTRIBUTE: e.g., \"mold\"] and [ATTRIBUTE: e.g., \"spores\"] in the house, so {s} an {f} for that")
            else:
                apparent7.append(f"Apparently we have [ATTRIBUTE: e.g., \"mold\"] and [ATTRIBUTE: e.g., \"spores\"] in the house, so {s} a {f} for that")

# %%
for a in apparent7:
    print(apparent7.index(a), a)
# Out:
# 0 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I'm looking for a filter for that
# 1 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I need a filter for that
# 2 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I want to invest in a filter for that
# 3 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I need to get a filter for that
# 4 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I need to grab a filter for that
# 5 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so someone told me to try a filter for that
# 6 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I'm here to shop for a filter for that
# ...

# %%
new7 = [] 

for f in fil7:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            new7.append(f"I just got a new [ATTRIBUTE: e.g., \"kitten\"] and I'm experiencing [ATTRIBUTE: e.g., \"asthma\"], so {s} {f} to help me")
        else:
            if 'air filter' in f:
                new7.append(f"I just got a new [ATTRIBUTE: e.g., \"kitten\"] and I'm experiencing [ATTRIBUTE: e.g., \"asthma\"], so {s} an {f} to help me")
            else:
                new7.append(f"I just got a new [ATTRIBUTE: e.g., \"kitten\"] and I'm experiencing [ATTRIBUTE: e.g., \"asthma\"], so {s} a {f} to help me")

# %%
for n in new7:
    print(new7.index(n), n)
# Out:
# 0 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so I'm looking for a filter to help me
# 1 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so I need a filter to help me
# 2 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so I want to invest in a filter to help me
# 3 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so I need to get a filter to help me
# 4 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so I need to grab a filter to help me
# 5 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so someone told me to try a filter to help me
# 6 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so I'm here to shop for a filter to help me
# ...

# %%
much7 = [] 

for f in fil7:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            much7.append(f"We have so much [ATTRIBUTE: e.g., \"lint\"] in the air that {s} {f} for that, but not too [ATTRIBUTE: e.g., \"expensive\"]")
        else:
            if 'air filter' in f:
                much7.append(f"We have so much [ATTRIBUTE: e.g., \"lint\"] in the air that {s} an {f} for that, but not too [ATTRIBUTE: e.g., \"expensive\"]")
            else:
                much7.append(f"We have so much [ATTRIBUTE: e.g., \"lint\"] in the air that {s} a {f} for that, but not too [ATTRIBUTE: e.g., \"expensive\"]")

# %%
for m in much7:
    print(much7.index(m), m)
# Out:
# 0 We have so much [ATTRIBUTE: e.g., "lint"] in the air that I'm looking for a filter for that, but not too [ATTRIBUTE: e.g., "expensive"]
# 1 We have so much [ATTRIBUTE: e.g., "lint"] in the air that I need a filter for that, but not too [ATTRIBUTE: e.g., "expensive"]
# 2 We have so much [ATTRIBUTE: e.g., "lint"] in the air that I want to invest in a filter for that, but not too [ATTRIBUTE: e.g., "expensive"]
# 3 We have so much [ATTRIBUTE: e.g., "lint"] in the air that I need to get a filter for that, but not too [ATTRIBUTE: e.g., "expensive"]
# 4 We have so much [ATTRIBUTE: e.g., "lint"] in the air that I need to grab a filter for that, but not too [ATTRIBUTE: e.g., "expensive"]
# 5 We have so much [ATTRIBUTE: e.g., "lint"] in the air that someone told me to try a filter for that, but not too [ATTRIBUTE: e.g., "expensive"]
# 6 We have so much [ATTRIBUTE: e.g., "lint"] in the air that I'm here to shop for a filter for that, but not too [ATTRIBUTE: e.g., "expensive"]
# ...

# %%
have7 = [] 

for f in fil7:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            have7.append(f"I haven't been [ATTRIBUTE: e.g., \"breathing\"] well, so {s} {f} for that and [ATTRIBUTE: e.g., \"pollen\"]")
        else:
            if 'air filter' in f:
                have7.append(f"I haven't been [ATTRIBUTE: e.g., \"breathing\"] well, so {s} an {f} for that and [ATTRIBUTE: e.g., \"pollen\"]")
            else:
                have7.append(f"I haven't been [ATTRIBUTE: e.g., \"breathing\"] well, so {s} a {f} for that and [ATTRIBUTE: e.g., \"pollen\"]")

# %%
for h in have7:
    print(have7.index(h), h)
# Out:
# 0 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I'm looking for a filter for that and [ATTRIBUTE: e.g., "pollen"]
# 1 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I need a filter for that and [ATTRIBUTE: e.g., "pollen"]
# 2 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I want to invest in a filter for that and [ATTRIBUTE: e.g., "pollen"]
# 3 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I need to get a filter for that and [ATTRIBUTE: e.g., "pollen"]
# 4 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I need to grab a filter for that and [ATTRIBUTE: e.g., "pollen"]
# 5 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so someone told me to try a filter for that and [ATTRIBUTE: e.g., "pollen"]
# 6 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I'm here to shop for a filter for that and [ATTRIBUTE: e.g., "pollen"]
# ...

# %%
lots7 = [] 

for f in fil7:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            lots7.append(f"I feel like there's lots of [ATTRIBUTE: e.g., \"germs\"] and [ATTRIBUTE: e.g., \"mold\"] in the air at my house, so {s} [ATTRIBUTE: e.g., \"inexpensive\"] {f} to help with that")
        else:
            lots7.append(f"I feel like there's lots of [ATTRIBUTE: e.g., \"germs\"] and [ATTRIBUTE: e.g., \"mold\"] in the air at my house, so {s} a [ATTRIBUTE: e.g., \"inexpensive\"] {f} to help with that")

# %%
for h in lots7:
    print(lots7.index(h), h)
# Out:
# 0 I feel like there's lots of [ATTRIBUTE: e.g., "germs"] and [ATTRIBUTE: e.g., "mold"] in the air at my house, so I'm looking for a [ATTRIBUTE: e.g., "inexpensive"] filter to help with that
# 1 I feel like there's lots of [ATTRIBUTE: e.g., "germs"] and [ATTRIBUTE: e.g., "mold"] in the air at my house, so I need a [ATTRIBUTE: e.g., "inexpensive"] filter to help with that
# 2 I feel like there's lots of [ATTRIBUTE: e.g., "germs"] and [ATTRIBUTE: e.g., "mold"] in the air at my house, so I want to invest in a [ATTRIBUTE: e.g., "inexpensive"] filter to help with that
# 3 I feel like there's lots of [ATTRIBUTE: e.g., "germs"] and [ATTRIBUTE: e.g., "mold"] in the air at my house, so I need to get a [ATTRIBUTE: e.g., "inexpensive"] filter to help with that
# 4 I feel like there's lots of [ATTRIBUTE: e.g., "germs"] and [ATTRIBUTE: e.g., "mold"] in the air at my house, so I need to grab a [ATTRIBUTE: e.g., "inexpensive"] filter to help with that
# ...

# %%
list7 = []

for s in s_s7:
    for f in fa7:
        if s is s_s7[2] or s is s_s7[5] or s is s_s7[7]:
            list7.append(f"{s} {f}")
        else:
            list7.append(f"{s} {f}")

# %%
list7_2 = list7[:] + apparent7[:] + new7[:] + much7[:] + have7[:] + lots7[:]

# %%
for l in list7_2:
    print(list7_2.index(l), l)
# Out:
# 0 I need the filter with the best [ATTRIBUTE: e.g., "MERV rating"]
# 1 I need the most [ATTRIBUTE: e.g., "superior"] filter with the best [ATTRIBUTE: e.g., "MERV rating"]
# 2 I need the most [ATTRIBUTE: e.g., "superior"] filter that has [ATTRIBUTE: e.g., "allergen defense"] and [ATTRIBUTE: e.g., "pet dander"] filtering
# 3 I need the most [ATTRIBUTE: e.g., "superior"] filter that is not [ATTRIBUTE: e.g., "flimsy"] and catches the [ATTRIBUTE: e.g., "clumps"] and [ATTRIBUTE: e.g., "dust"] in the air
# 4 I need the most [ATTRIBUTE: e.g., "superior"] filter for [ATTRIBUTE: e.g., "dust"]
# 5 I need the most [ATTRIBUTE: e.g., "superior"] filter for [ATTRIBUTE: e.g., "smoke odor"] problems
# 6 I need the most [ATTRIBUTE: e.g., "superior"] filter with lots of [ATTRIBUTE: e.g., "pleating"] that catches [ATTRIBUTE: e.g., "pet hair"]
# ...

# %%
case7_test = open('Case7.txt', 'w')

case7_test.write('\n'.join(sorted(list(set(list7_2)))))

case7_test.close()

# %%
#Case 8

# %%
fil8 = ['filter', 'air filter', 'filters', 'air filters']

# %%
a8sg = ['with [ATTRIBUTE: e.g., \"allergen defense\"]', 'that\'s good for [ATTRIBUTE: e.g., \"pollen\"]', 'that can pick up [ATTRIBUTE: e.g., \"viruses\"] and [ATTRIBUTE: e.g., \"mold\"]', 'with lots of [ATTRIBUTE: e.g., \"pleating\"] that picks up [ATTRIBUTE: e.g., \"pet hair\"]', 'for [ATTRIBUTE: e.g., \"cat dander\"]', 'that has a good [ATTRIBUTE: e.g., \"customer rating\"], is not too [ATTRIBUTE: e.g., \"expensive\"] and seems [ATTRIBUTE: e.g., \"durable\"]', 'for the house that traps [ATTRIBUTE: e.g., \"lint\"] and is not too [ATTRIBUTE: e.g., \"expensive\"]', 'to catch the [ATTRIBUTE: e.g., \"particulates\"] in the air, but isn\'t going to [ATTRIBUTE: e.g., \"cost much\"]', 'that isn\'t too [ATTRIBUTE: e.g., \"generic looking\"]', 'that gets [ATTRIBUTE: \"lint\"] out of the air', 'that [ATTRIBUTE: e.g., \"looks good\"] and has a [ATTRIBUTE: e.g., \"good evaluation\"] but is [ATTRIBUTE: e.g., \"cheap\"], please', 'you have with a good [ATTRIBUTE: e.g., \"rating\"] that I don\'t have to [ATTRIBUTE: e.g., \"replace\"] too often', 'to get a [ATTRIBUTE: e.g., \"smoke smell\"] out of the air', 'for [ATTRIBUTE: e.g., \"fungus\"], [ATTRIBUTE: e.g., \"mold\"], and [ATTRIBUTE: e.g., \"spores\"]', 'that can help with [ATTRIBUTE: e.g., \"dirt\"] and has good [ATTRIBUTE: e.g., \"performance\"]', 'that has good [ATTRIBUTE: e.g., \"material\"] and [ATTRIBUTE: e.g., \"looks expensive\"]']

# %%
for a in a8sg:
    print(a8sg.index(a), a)
# Out:
# 0 with [ATTRIBUTE: e.g., "allergen defense"]
# 1 that's good for [ATTRIBUTE: e.g., "pollen"]
# 2 that can pick up [ATTRIBUTE: e.g., "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 3 with lots of [ATTRIBUTE: e.g., "pleating"] that picks up [ATTRIBUTE: e.g., "pet hair"]
# 4 for [ATTRIBUTE: e.g., "cat dander"]
# 5 that has a good [ATTRIBUTE: e.g., "customer rating"], is not too [ATTRIBUTE: e.g., "expensive"] and seems [ATTRIBUTE: e.g., "durable"]
# 6 for the house that traps [ATTRIBUTE: e.g., "lint"] and is not too [ATTRIBUTE: e.g., "expensive"]
# 7 to catch the [ATTRIBUTE: e.g., "particulates"] in the air, but isn't going to [ATTRIBUTE: e.g., "cost much"]
# 8 that isn't too [ATTRIBUTE: e.g., "generic looking"]
# 9 that gets [ATTRIBUTE: "lint"] out of the air
# 10 that [ATTRIBUTE: e.g., "looks good"] and has a [ATTRIBUTE: e.g., "good evaluation"] but is [ATTRIBUTE: e.g., "cheap"], please
# ...

# %%
a8pl = ['with [ATTRIBUTE: e.g., \"allergen defense\"]', 'that are good for [ATTRIBUTE: e.g., \"pollen\"]', 'that can pick up [ATTRIBUTE: e.g., \"viruses\"] and [ATTRIBUTE: e.g., \"mold\"]', 'with lots of [ATTRIBUTE: e.g., \"pleating\"] that pick up [ATTRIBUTE: e.g., \"pet hair\"]', 'for [ATTRIBUTE: e.g., \"cat dander\"]', 'that have a good [ATTRIBUTE: e.g., \"customer rating\"], are not too [ATTRIBUTE: e.g., \"expensive\"] and seem [ATTRIBUTE: e.g., \"durable\"]', 'for the house that trap [ATTRIBUTE: e.g., \"lint\"] and are not too [ATTRIBUTE: e.g., \"expensive\"]', 'to catch the [ATTRIBUTE: e.g., \"particulates\"] in the air, but aren\'t going to [ATTRIBUTE: e.g., \"cost much\"]', 'that aren\'t too [ATTRIBUTE: e.g., \"generic looking\"]', 'that get [ATTRIBUTE: \"lint\"] out of the air', 'that [ATTRIBUTE: e.g., \"look good\"] and have a [ATTRIBUTE: e.g., \"good evaluation\"] but are [ATTRIBUTE: e.g., \"cheap\"], please', 'you have with a good [ATTRIBUTE: e.g., \"rating\"] that I don\'t have to [ATTRIBUTE: e.g., \"replace\"] too often', 'to get a [ATTRIBUTE: e.g., \"smoke smell\"] out of the air', 'for [ATTRIBUTE: e.g., \"fungus\"], [ATTRIBUTE: e.g., \"mold\"], and [ATTRIBUTE: e.g., \"spores\"]', 'that can help with [ATTRIBUTE: e.g., \"dirt\"] and have good [ATTRIBUTE: e.g., \"performance\"]', 'that have good [ATTRIBUTE: e.g., \"material\"] and [ATTRIBUTE: e.g., \"look expensive\"]']

# %%
for a in a8pl:
    print(a8pl.index(a), a)
# Out:
# 0 with [ATTRIBUTE: e.g., "allergen defense"]
# 1 that are good for [ATTRIBUTE: e.g., "pollen"]
# 2 that can pick up [ATTRIBUTE: e.g., "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 3 with lots of [ATTRIBUTE: e.g., "pleating"] that pick up [ATTRIBUTE: e.g., "pet hair"]
# 4 for [ATTRIBUTE: e.g., "cat dander"]
# 5 that have a good [ATTRIBUTE: e.g., "customer rating"], are not too [ATTRIBUTE: e.g., "expensive"] and seem [ATTRIBUTE: e.g., "durable"]
# 6 for the house that trap [ATTRIBUTE: e.g., "lint"] and are not too [ATTRIBUTE: e.g., "expensive"]
# 7 to catch the [ATTRIBUTE: e.g., "particulates"] in the air, but aren't going to [ATTRIBUTE: e.g., "cost much"]
# 8 that aren't too [ATTRIBUTE: e.g., "generic looking"]
# 9 that get [ATTRIBUTE: "lint"] out of the air
# 10 that [ATTRIBUTE: e.g., "look good"] and have a [ATTRIBUTE: e.g., "good evaluation"] but are [ATTRIBUTE: e.g., "cheap"], please
# ...

# %%
ab8 = ['[ATTRIBUTE: e.g., \"inexpensive\"] [BRAND: e.g., \"3M\"]', '[BRAND: e.g., \"3M\"]', '[ATTRIBUTE: e.g., \"sturdy\"], [ATTRIBUTE: e.g., \"cheap\"] [BRAND: e.g., \"3M\"]', 'the [ATTRIBUTE: e.g., \"inexpesive\"] [BRAND: e.g., \"3M\"]', 'the most [ATTRIBUTE: e.g., \"economic\"] [BRAND: e.g., \"3M\"]']

# %%
abf8 = []

for a in ab8:
    for f in fil8:
        if 'filters' in f:
            abf8.append(f"{a} {f}")
        else:
            if 'the' in a:
                abf8.append(f"{a} {f}")
            else:
                abf8.append(f"a {a} {f}")

# %%
brand8 = ['a [BRAND: e.g., \"3M\"]']

# %%
fabf8 = abf8[:] + brand8[:]

# %%
for f in fabf8:
    print(fabf8.index(f), f)
# Out:
# 0 a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter
# 1 a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] air filter
# 2 [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filters
# 3 [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] air filters
# 4 a [BRAND: e.g., "3M"] filter
# 5 a [BRAND: e.g., "3M"] air filter
# 6 [BRAND: e.g., "3M"] filters
# 7 [BRAND: e.g., "3M"] air filters
# 8 a [ATTRIBUTE: e.g., "sturdy"], [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] filter
# 9 a [ATTRIBUTE: e.g., "sturdy"], [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] air filter
# 10 [ATTRIBUTE: e.g., "sturdy"], [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] filters
# 11 [ATTRIBUTE: e.g., "sturdy"], [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] air filters
# 12 the [ATTRIBUTE: e.g., "inexpesive"] [BRAND: e.g., "3M"] filter
# 13 the [ATTRIBUTE: e.g., "inexpesive"] [BRAND: e.g., "3M"] air filter
# 14 the [ATTRIBUTE: e.g., "inexpesive"] [BRAND: e.g., "3M"] filters
# ...

# %%
full8 = []

for f in fabf8:
    if 'filters' in f:
        for a in a8pl:
            full8.append(f"{f} {a}")
    else:
        for a in a8sg:
            full8.append(f"{f} {a}")

# %%
for f in full8:
    print(full8.index(f), f)
# Out:
# 0 a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter with [ATTRIBUTE: e.g., "allergen defense"]
# 1 a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter that's good for [ATTRIBUTE: e.g., "pollen"]
# 2 a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter that can pick up [ATTRIBUTE: e.g., "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 3 a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter with lots of [ATTRIBUTE: e.g., "pleating"] that picks up [ATTRIBUTE: e.g., "pet hair"]
# 4 a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter for [ATTRIBUTE: e.g., "cat dander"]
# 5 a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter that has a good [ATTRIBUTE: e.g., "customer rating"], is not too [ATTRIBUTE: e.g., "expensive"] and seems [ATTRIBUTE: e.g., "durable"]
# 6 a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter for the house that traps [ATTRIBUTE: e.g., "lint"] and is not too [ATTRIBUTE: e.g., "expensive"]
# ...

# %%
s_s8 = ['I\'m looking for', 'Do you have', 'I want', 'I like', 'I\'d like', 'Can you show me', 'Do y\'all have', 'I am looking for', 'I\'m here to pick up', 'While I\'m here, I need']

# %%
for s in s_s8:
    print(s_s8.index(s), s)
# Out:
# 0 I'm looking for
# 1 Do you have
# 2 I want
# 3 I like
# 4 I'd like
# 5 Can you show me
# 6 Do y'all have
# 7 I am looking for
# 8 I'm here to pick up
# 9 While I'm here, I need

# %%
apparent8 = []

for f in fil8:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            apparent8.append(f"Apparently we have [ATTRIBUTE: e.g., \"mold\"] and [ATTRIBUTE: e.g., \"spores\"] in the house, so {s} [BRAND: e.g., \"3M\"] {f} for that")
        else:
            apparent8.append(f"Apparently we have [ATTRIBUTE: e.g., \"mold\"] and [ATTRIBUTE: e.g., \"spores\"] in the house, so {s} a [BRAND: e.g., \"3M\"] {f} for that")

# %%
for a in apparent8:
    print(apparent8.index(a), a)
# Out:
# 0 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I'm looking for a [BRAND: e.g., "3M"] filter for that
# 1 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I need a [BRAND: e.g., "3M"] filter for that
# 2 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I want to invest in a [BRAND: e.g., "3M"] filter for that
# 3 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I need to get a [BRAND: e.g., "3M"] filter for that
# 4 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I need to grab a [BRAND: e.g., "3M"] filter for that
# 5 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so someone told me to try a [BRAND: e.g., "3M"] filter for that
# ...

# %%
new8 = [] 

for f in fil8:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            new8.append(f"I just got a new [ATTRIBUTE: e.g., \"kitten\"] and I'm experiencing [ATTRIBUTE: e.g., \"asthma\"], so {s} [BRAND: e.g., \"3M\"] {f} to help me")
        else:
            new8.append(f"I just got a new [ATTRIBUTE: e.g., \"kitten\"] and I'm experiencing [ATTRIBUTE: e.g., \"asthma\"], so {s} a [BRAND: e.g., \"3M\"] {f} to help me")

# %%
for n in new8:
    print(new8.index(n), n)
# Out:
# 0 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so I'm looking for a [BRAND: e.g., "3M"] filter to help me
# 1 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so I need a [BRAND: e.g., "3M"] filter to help me
# 2 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so I want to invest in a [BRAND: e.g., "3M"] filter to help me
# 3 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so I need to get a [BRAND: e.g., "3M"] filter to help me
# 4 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so I need to grab a [BRAND: e.g., "3M"] filter to help me
# 5 I just got a new [ATTRIBUTE: e.g., "kitten"] and I'm experiencing [ATTRIBUTE: e.g., "asthma"], so someone told me to try a [BRAND: e.g., "3M"] filter to help me
# ...

# %%
have8 = [] 

for f in fil8:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            have8.append(f"I haven't been [ATTRIBUTE: e.g., \"breathing\"] well, so {s} [BRAND: e.g., \"3M\"] {f} for that and [ATTRIBUTE: e.g., \"pollen\"] in the air")
        else:
            have8.append(f"I haven't been [ATTRIBUTE: e.g., \"breathing\"] well, so {s} a [BRAND: e.g., \"3M\"] {f} for that and [ATTRIBUTE: e.g., \"pollen\"] in the air")

# %%
for h in have8:
    print(have8.index(h), h)
# Out:
# 0 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I'm looking for a [BRAND: e.g., "3M"] filter for that and [ATTRIBUTE: e.g., "pollen"] in the air
# 1 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I need a [BRAND: e.g., "3M"] filter for that and [ATTRIBUTE: e.g., "pollen"] in the air
# 2 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I want to invest in a [BRAND: e.g., "3M"] filter for that and [ATTRIBUTE: e.g., "pollen"] in the air
# 3 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I need to get a [BRAND: e.g., "3M"] filter for that and [ATTRIBUTE: e.g., "pollen"] in the air
# 4 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I need to grab a [BRAND: e.g., "3M"] filter for that and [ATTRIBUTE: e.g., "pollen"] in the air
# 5 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so someone told me to try a [BRAND: e.g., "3M"] filter for that and [ATTRIBUTE: e.g., "pollen"] in the air
# ...

# %%
lots8 = [] 

for f in fil7:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            lots8.append(f"There's lots of [ATTRIBUTE: e.g., \"pollen\"] and [ATTRIBUTE: e.g., \"mold\"] in the air, so {s} [BRAND: e.g., \"3M\"] {f} for that")
        else:
            lots8.append(f"There's lots of [ATTRIBUTE: e.g., \"pollen\"] and [ATTRIBUTE: e.g., \"mold\"] in the air, so {s} a [BRAND: e.g., \"3M\"] {f} for that")

# %%
for l in lots8:
    print(lots8.index(l), l)
# Out:
# 0 There's lots of [ATTRIBUTE: e.g., "pollen"] and [ATTRIBUTE: e.g., "mold"] in the air, so I'm looking for a [BRAND: e.g., "3M"] filter for that
# 1 There's lots of [ATTRIBUTE: e.g., "pollen"] and [ATTRIBUTE: e.g., "mold"] in the air, so I need a [BRAND: e.g., "3M"] filter for that
# 2 There's lots of [ATTRIBUTE: e.g., "pollen"] and [ATTRIBUTE: e.g., "mold"] in the air, so I want to invest in a [BRAND: e.g., "3M"] filter for that
# 3 There's lots of [ATTRIBUTE: e.g., "pollen"] and [ATTRIBUTE: e.g., "mold"] in the air, so I need to get a [BRAND: e.g., "3M"] filter for that
# 4 There's lots of [ATTRIBUTE: e.g., "pollen"] and [ATTRIBUTE: e.g., "mold"] in the air, so I need to grab a [BRAND: e.g., "3M"] filter for that
# 5 There's lots of [ATTRIBUTE: e.g., "pollen"] and [ATTRIBUTE: e.g., "mold"] in the air, so someone told me to try a [BRAND: e.g., "3M"] filter for that
# ...

# %%
list8 = []

for s in s_s8:
    for f in full8:
        if s is s_s8[1] or s is s_s8[5] or s is s_s8[6]:
            list8.append(f"{s} {f}?")
        else:
            list8.append(f"{s} {f}")

# %%
list8_2 = list8[:] + apparent8[:] + new8[:] + have8[:] + lots8[:]

# %%
for l in list8_2:
    print(list8_2.index(l), l)
# Out:
# 0 I'm looking for a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter with [ATTRIBUTE: e.g., "allergen defense"]
# 1 I'm looking for a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter that's good for [ATTRIBUTE: e.g., "pollen"]
# 2 I'm looking for a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter that can pick up [ATTRIBUTE: e.g., "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 3 I'm looking for a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter with lots of [ATTRIBUTE: e.g., "pleating"] that picks up [ATTRIBUTE: e.g., "pet hair"]
# 4 I'm looking for a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter for [ATTRIBUTE: e.g., "cat dander"]
# 5 I'm looking for a [ATTRIBUTE: e.g., "inexpensive"] [BRAND: e.g., "3M"] filter that has a good [ATTRIBUTE: e.g., "customer rating"], is not too [ATTRIBUTE: e.g., "expensive"] and seems [ATTRIBUTE: e.g., "durable"]
# ...

# %%
case8_test = open('Case8.txt', 'w')

case8_test.write('\n'.join(sorted(list(set(list8_2)))))

case8_test.close()

# %%
#Case 9

# %%
fil9 = ['filter', 'air filter', 'filters', 'air filters']

# %%
a9sg = ['with [ATTRIBUTE: e.g., \"allergen defense\"]', 'that\'s good for [ATTRIBUTE: e.g., \"pollen\"]', 'that can pick up [ATTRIBUTE: e.g., \"viruses\"] and [ATTRIBUTE: e.g., \"mold\"]', 'with a lot of [ATTRIBUTE: e.g., \"pleating\"] and [ATTRIBUTE: e.g., \"durability\"]', 'for [ATTRIBUTE: e.g., \"pet hair\"]', 'that has a good [ATTRIBUTE: e.g., \"customer rating\"], is not too [ATTRIBUTE: e.g., \"expensive\"], and seems [ATTRIBUTE: e.g., \"durable\"]', 'for the house that traps [ATTRIBUTE: e.g., \"lint\"] and is not too [ATTRIBUTE: e.g., \"expensive\"]', 'to catch the [ATTRIBUTE: e.g., \"particulates\"] in the air, but isn\'t going to [ATTRIBUTE: e.g., \"cost\"] much', 'that isn\'t too [ATTRIBUTE: e.g., \"generic looking\"]', 'that gets [ATTRIBUTE: e.g., \"lint\"] out of the air', 'that [ATTRIBUTE: e.g., \"looks good\"] and has a [ATTRIBUTE: e.g., \"good evaluation\"] but is [ATTRIBUTE: e.g., \"cheap\"], please', 'you have please', 'to get [ATTRIBUTE: e.g., \"smoke smell\"] out of the air', 'for [ATTRIBUTE: e.g., \"fungus\"], [ATTRIBUTE: e.g., \"mold\"], and [ATTRIBUTE: e.g., \"spores\"]', 'that has good [ATTRIBUTE: e.g., \"material\"]']

# %%
for a in a9sg:
    print(a9sg.index(a), a)
# Out:
# 0 with [ATTRIBUTE: e.g., "allergen defense"]
# 1 that's good for [ATTRIBUTE: e.g., "pollen"]
# 2 that can pick up [ATTRIBUTE: e.g., "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 3 with a lot of [ATTRIBUTE: e.g., "pleating"] and [ATTRIBUTE: e.g., "durability"]
# 4 for [ATTRIBUTE: e.g., "pet hair"]
# 5 that has a good [ATTRIBUTE: e.g., "customer rating"], is not too [ATTRIBUTE: e.g., "expensive"], and seems [ATTRIBUTE: e.g., "durable"]
# 6 for the house that traps [ATTRIBUTE: e.g., "lint"] and is not too [ATTRIBUTE: e.g., "expensive"]
# 7 to catch the [ATTRIBUTE: e.g., "particulates"] in the air, but isn't going to [ATTRIBUTE: e.g., "cost"] much
# 8 that isn't too [ATTRIBUTE: e.g., "generic looking"]
# 9 that gets [ATTRIBUTE: e.g., "lint"] out of the air
# 10 that [ATTRIBUTE: e.g., "looks good"] and has a [ATTRIBUTE: e.g., "good evaluation"] but is [ATTRIBUTE: e.g., "cheap"], please
# 11 you have please
# 12 to get [ATTRIBUTE: e.g., "smoke smell"] out of the air
# ...

# %%
a9pl = ['with [ATTRIBUTE: e.g., \"allergen defense\"]', 'that are good for [ATTRIBUTE: e.g., \"pollen\"]', 'that can pick up [ATTRIBUTE: e.g., \"viruses\"] and [ATTRIBUTE: e.g., \"mold\"]', 'with a lot of [ATTRIBUTE: e.g., \"pleating\"] and [ATTRIBUTE: e.g., \"durability\"]', 'for [ATTRIBUTE: e.g., \"pet hair\"]', 'that have a good [ATTRIBUTE: e.g., \"customer rating\"], are not too [ATTRIBUTE: e.g., \"expensive\"], and seem [ATTRIBUTE: e.g., \"durable\"]', 'for the house that trap [ATTRIBUTE: e.g., \"lint\"] and are not too [ATTRIBUTE: e.g., \"expensive\"]', 'to catch the [ATTRIBUTE: e.g., \"particulates\"] in the air, but aren\'t going to [ATTRIBUTE: e.g., \"cost\"] much', 'that aren\'t too [ATTRIBUTE: e.g., \"generic looking\"]', 'that get [ATTRIBUTE: e.g., \"lint\"] out of the air', 'that [ATTRIBUTE: e.g., \"look good\"] and have a [ATTRIBUTE: e.g., \"good evaluation\"] but are [ATTRIBUTE: e.g., \"cheap\"], please', 'you have please', 'to get [ATTRIBUTE: e.g., \"smoke smell\"] out of the air', 'for [ATTRIBUTE: e.g., \"fungus\"], [ATTRIBUTE: e.g., \"mold\"], and [ATTRIBUTE: e.g., \"spores\"]', 'that have good [ATTRIBUTE: e.g., \"material\"]']

# %%
for a in a9pl:
    print(a9pl.index(a), a)
# Out:
# 0 with [ATTRIBUTE: e.g., "allergen defense"]
# 1 that are good for [ATTRIBUTE: e.g., "pollen"]
# 2 that can pick up [ATTRIBUTE: e.g., "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 3 with a lot of [ATTRIBUTE: e.g., "pleating"] and [ATTRIBUTE: e.g., "durability"]
# 4 for [ATTRIBUTE: e.g., "pet hair"]
# 5 that have a good [ATTRIBUTE: e.g., "customer rating"], are not too [ATTRIBUTE: e.g., "expensive"], and seem [ATTRIBUTE: e.g., "durable"]
# 6 for the house that trap [ATTRIBUTE: e.g., "lint"] and are not too [ATTRIBUTE: e.g., "expensive"]
# 7 to catch the [ATTRIBUTE: e.g., "particulates"] in the air, but aren't going to [ATTRIBUTE: e.g., "cost"] much
# 8 that aren't too [ATTRIBUTE: e.g., "generic looking"]
# 9 that get [ATTRIBUTE: e.g., "lint"] out of the air
# 10 that [ATTRIBUTE: e.g., "look good"] and have a [ATTRIBUTE: e.g., "good evaluation"] but are [ATTRIBUTE: e.g., "cheap"], please
# 11 you have please
# 12 to get [ATTRIBUTE: e.g., "smoke smell"] out of the air
# ...

# %%
ab9 = ['[BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"]', 'the [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"]', '[ATTRIBUTE: e.g., \"cheap\"] [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"]', '[BRAND: e.g., \"3M\"], [BRAND: e.g., \"Honeywell\"], or [BRAND: e.g., \"Nordic Pure\"]', '[BRAND: e.g., \"3M\"]', '[ATTRIBUTE: e.g., \"sturdy\"], [ATTRIBUTE: e.g., \"cheap\"] [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"]', '[BRAND: e.g., \"3M\"] and [BRAND: e.g., \"Nordic Pure\"]', 'the most [ATTRIBUTE: e.g., \"economic\"] [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"]']

# %%
for a in ab9:
    print(ab9.index(a), a)
# Out:
# 0 [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"]
# 1 the [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"]
# 2 [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"]
# 3 [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND: e.g., "Nordic Pure"]
# 4 [BRAND: e.g., "3M"]
# 5 [ATTRIBUTE: e.g., "sturdy"], [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"]
# 6 [BRAND: e.g., "3M"] and [BRAND: e.g., "Nordic Pure"]
# 7 the most [ATTRIBUTE: e.g., "economic"] [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"]

# %%
abf9 = []

for a in ab9:
    for f in fil9:
        abf9.append(f"{a} {f}")

# %%
for a in abf9:
    print(abf9.index(a), a)
# Out:
# 0 [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter
# 1 [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] air filter
# 2 [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filters
# 3 [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] air filters
# 4 the [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter
# 5 the [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] air filter
# 6 the [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filters
# 7 the [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] air filters
# 8 [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter
# 9 [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] air filter
# 10 [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filters
# 11 [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] air filters
# ...

# %%
com_abf9 = abf9[:24] + abf9[26:]

# %%
for c in com_abf9:
    print(com_abf9.index(c), c)
# Out:
# 0 [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter
# 1 [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] air filter
# 2 [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filters
# 3 [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] air filters
# 4 the [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter
# 5 the [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] air filter
# 6 the [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filters
# 7 the [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] air filters
# 8 [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter
# 9 [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] air filter
# 10 [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filters
# 11 [ATTRIBUTE: e.g., "cheap"] [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] air filters
# ...

# %%
abfa9 = []

for c in com_abf9:
    if 'filters' in c:
        for a in a9pl:
            abfa9.append(f"{c} {a}")
    else:
        if 'the' in c:
            for a in a9sg:
                abfa9.append(f"{c} {a}")
        else:
            for b in a9sg:
                abfa9.append(f"a {c} {b}")

# %%
for a in abfa9:
    print(abfa9.index(a), a)
# Out:
# 0 a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter with [ATTRIBUTE: e.g., "allergen defense"]
# 1 a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter that's good for [ATTRIBUTE: e.g., "pollen"]
# 2 a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter that can pick up [ATTRIBUTE: e.g., "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 3 a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter with a lot of [ATTRIBUTE: e.g., "pleating"] and [ATTRIBUTE: e.g., "durability"]
# 4 a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for [ATTRIBUTE: e.g., "pet hair"]
# 5 a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter that has a good [ATTRIBUTE: e.g., "customer rating"], is not too [ATTRIBUTE: e.g., "expensive"], and seems [ATTRIBUTE: e.g., "durable"]
# 6 a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for the house that traps [ATTRIBUTE: e.g., "lint"] and is not too [ATTRIBUTE: e.g., "expensive"]
# ...

# %%
s_s9 = ['I\'m looking for', 'Do you have', 'I want', 'I like', 'I\'d like', 'I want to look at', 'Can you show me', 'Do y\'all have', 'I\'m here to pick up']

# %%
for s in s_s9:
    print(s_s9.index(s), s)
# Out:
# 0 I'm looking for
# 1 Do you have
# 2 I want
# 3 I like
# 4 I'd like
# 5 I want to look at
# 6 Can you show me
# 7 Do y'all have
# 8 I'm here to pick up

# %%
apparent9 = []

for f in fil9:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            apparent9.append(f"Apparently we have [ATTRIBUTE: e.g., \"mold\"] and [ATTRIBUTE: e.g., \"spores\"] in the house, so {s} [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"] {f} for that")
        else:
            apparent9.append(f"Apparently we have [ATTRIBUTE: e.g., \"mold\"] and [ATTRIBUTE: e.g., \"spores\"] in the house, so {s} a [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"] {f} for that")

# %%
for a in apparent9:
    print(apparent9.index(a), a)
# Out:
# 0 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I'm looking for a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that
# 1 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I need a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that
# 2 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I want to invest in a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that
# 3 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I need to get a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that
# 4 Apparently we have [ATTRIBUTE: e.g., "mold"] and [ATTRIBUTE: e.g., "spores"] in the house, so I need to grab a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that
# ...

# %%
have9 = [] 

for f in fil9:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            have9.append(f"I haven't been [ATTRIBUTE: e.g., \"breathing\"] well, so {s} [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"] {f} for that and [ATTRIBUTE: e.g., \"pollen\"] in the air")
        else:
            have9.append(f"I haven't been [ATTRIBUTE: e.g., \"breathing\"] well, so {s} a [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"] {f} for that and [ATTRIBUTE: e.g., \"pollen\"] in the air")

# %%
for h in have9:
    print(have9.index(h), h)
# Out:
# 0 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I'm looking for a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that and [ATTRIBUTE: e.g., "pollen"] in the air
# 1 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I need a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that and [ATTRIBUTE: e.g., "pollen"] in the air
# 2 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I want to invest in a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that and [ATTRIBUTE: e.g., "pollen"] in the air
# 3 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I need to get a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that and [ATTRIBUTE: e.g., "pollen"] in the air
# 4 I haven't been [ATTRIBUTE: e.g., "breathing"] well, so I need to grab a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that and [ATTRIBUTE: e.g., "pollen"] in the air
# ...

# %%
lots9 = [] 

for f in fil9:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            lots9.append(f"There's lots of [ATTRIBUTE: e.g., \"pollen\"] and [ATTRIBUTE: e.g., \"mold\"] in the air, so {s} [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"] {f} for that")
        else:
            lots9.append(f"There's lots of [ATTRIBUTE: e.g., \"pollen\"] and [ATTRIBUTE: e.g., \"mold\"] in the air, so {s} a [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"] {f} for that")

# %%
for l in lots9:
    print(lots9.index(l), l)
# Out:
# 0 There's lots of [ATTRIBUTE: e.g., "pollen"] and [ATTRIBUTE: e.g., "mold"] in the air, so I'm looking for a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that
# 1 There's lots of [ATTRIBUTE: e.g., "pollen"] and [ATTRIBUTE: e.g., "mold"] in the air, so I need a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that
# 2 There's lots of [ATTRIBUTE: e.g., "pollen"] and [ATTRIBUTE: e.g., "mold"] in the air, so I want to invest in a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that
# 3 There's lots of [ATTRIBUTE: e.g., "pollen"] and [ATTRIBUTE: e.g., "mold"] in the air, so I need to get a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that
# 4 There's lots of [ATTRIBUTE: e.g., "pollen"] and [ATTRIBUTE: e.g., "mold"] in the air, so I need to grab a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for that
# ...

# %%
either9 = [] 

for f in fil9:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            either9.append(f"{s} either [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"] {f} that can pick up [ATTRIBUTE: e.g. \"viruses\"] and [ATTRIBUTE: e.g., \"mold\"]")
        else:
            either9.append(f"{s} either a [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"] {f} that can pick up [ATTRIBUTE: e.g. \"viruses\"] and [ATTRIBUTE: e.g., \"mold\"]")

# %%
for e in either9:
    print(either9.index(e), e)
# Out:
# 0 I'm looking for either a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter that can pick up [ATTRIBUTE: e.g. "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 1 I need either a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter that can pick up [ATTRIBUTE: e.g. "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 2 I want to invest in either a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter that can pick up [ATTRIBUTE: e.g. "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 3 I need to get either a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter that can pick up [ATTRIBUTE: e.g. "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 4 I need to grab either a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter that can pick up [ATTRIBUTE: e.g. "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 5 someone told me to try either a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter that can pick up [ATTRIBUTE: e.g. "viruses"] and [ATTRIBUTE: e.g., "mold"]
# ...

# %%
list9 = []

for s in s_s9:
    for a in abfa9:
        if s is s_s9[1] or s is s_s9[7] or s is s_s9[8]:
            list9.append(f"{s} {a}?")
        else:
            list9.append(f"{s} {a}")

# %%
list9_2 = list9[:] + apparent9[:] + have9[:] + lots9[:] + either9[:]

# %%
for l in list9_2:
    print(list9_2.index(l), l)
# Out:
# 0 I'm looking for a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter with [ATTRIBUTE: e.g., "allergen defense"]
# 1 I'm looking for a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter that's good for [ATTRIBUTE: e.g., "pollen"]
# 2 I'm looking for a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter that can pick up [ATTRIBUTE: e.g., "viruses"] and [ATTRIBUTE: e.g., "mold"]
# 3 I'm looking for a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter with a lot of [ATTRIBUTE: e.g., "pleating"] and [ATTRIBUTE: e.g., "durability"]
# 4 I'm looking for a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter for [ATTRIBUTE: e.g., "pet hair"]
# 5 I'm looking for a [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"] filter that has a good [ATTRIBUTE: e.g., "customer rating"], is not too [ATTRIBUTE: e.g., "expensive"], and seems [ATTRIBUTE: e.g., "durable"]
# ...

# %%
case9_test = open('Case9.txt', 'w')

case9_test.write('\n'.join(sorted(list(set(list9_2)))))

case9_test.close()

# %%
#Case 10

# %%
fil10 = ['filter', 'air filter', 'filters', 'air filters']

# %%
b10 = ['[BRAND: e.g., \"3M\"] or [BRAND:e.g., \"Nordic Pure\"]', '[BRAND: e.g., \"3M\"], [BRAND: e.g., \"Honeywell\"], or [BRAND:e.g., \"Nordic Pure\"]', '[BRAND: e.g., \"3M\"] and [BRAND:e.g., \"Nordic Pure\"]']

# %%
fb10 = []

for b in b10:
    for f in fil10:
        if 'filters' in f:
            fb10.append(f"{b} {f}")
        else:
            fb10.append(f"a {b} {f}")
        
for f in fil10:
    if 'filters' in f:
        fb10.append(f"[BRAND: e.g., \"3M\"] {f} or [BRAND: e.g., \"Nordic Pure\"] {f}")
    else:
        fb10.append(f"a [BRAND: e.g., \"3M\"] {f} or [BRAND: e.g., \"Nordic Pure\"] {f}")

# %%
fb10.remove(fb10[8])

# %%
fb10.remove(fb10[8])

# %%
for f in fb10:
    print(fb10.index(f), f)
# Out:
# 0 a [BRAND: e.g., "3M"] or [BRAND:e.g., "Nordic Pure"] filter
# 1 a [BRAND: e.g., "3M"] or [BRAND:e.g., "Nordic Pure"] air filter
# 2 [BRAND: e.g., "3M"] or [BRAND:e.g., "Nordic Pure"] filters
# 3 [BRAND: e.g., "3M"] or [BRAND:e.g., "Nordic Pure"] air filters
# 4 a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND:e.g., "Nordic Pure"] filter
# 5 a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND:e.g., "Nordic Pure"] air filter
# 6 [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND:e.g., "Nordic Pure"] filters
# 7 [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND:e.g., "Nordic Pure"] air filters
# 8 [BRAND: e.g., "3M"] and [BRAND:e.g., "Nordic Pure"] filters
# 9 [BRAND: e.g., "3M"] and [BRAND:e.g., "Nordic Pure"] air filters
# 10 a [BRAND: e.g., "3M"] filter or [BRAND: e.g., "Nordic Pure"] filter
# 11 a [BRAND: e.g., "3M"] air filter or [BRAND: e.g., "Nordic Pure"] air filter
# 12 [BRAND: e.g., "3M"] filters or [BRAND: e.g., "Nordic Pure"] filters
# ...

# %%
s_s10 = ['I\'m looking for', 'I think I need', 'Do you have', 'Can I buy', 'I am here to buy', 'I want to look at', 'I\'m shopping for', 'While I\'m here, I need to purchase', 'Here to pick up', 'Can you help me with', 'Looking to purchase', 'Would you mind telling me about', 'I\'m interested in']

# %%
for s in s_s10:
    print(s_s10.index(s), s)
# Out:
# 0 I'm looking for
# 1 I think I need
# 2 Do you have
# 3 Can I buy
# 4 I am here to buy
# 5 I want to look at
# 6 I'm shopping for
# 7 While I'm here, I need to purchase
# 8 Here to pick up
# 9 Can you help me with
# 10 Looking to purchase
# 11 Would you mind telling me about
# 12 I'm interested in

# %%
either10 = [] 

for f in fil10:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            either10.append(f"{s} either [BRAND: e.g., \"3M\"], [BRAND: e.g., \"Honeywell\"], or [BRAND: e.g., \"Nordic Pure\"] {f}")
        else:
            either10.append(f"{s} either a [BRAND: e.g., \"3M\"], [BRAND: e.g., \"Honeywell\"], or [BRAND: e.g., \"Nordic Pure\"] {f}")

# %%
for e in either10:
    print(either10.index(e), e)
# Out:
# 0 I'm looking for either a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND: e.g., "Nordic Pure"] filter
# 1 I need either a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND: e.g., "Nordic Pure"] filter
# 2 I want to invest in either a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND: e.g., "Nordic Pure"] filter
# 3 I need to get either a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND: e.g., "Nordic Pure"] filter
# 4 I need to grab either a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND: e.g., "Nordic Pure"] filter
# 5 someone told me to try either a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND: e.g., "Nordic Pure"] filter
# 6 I'm here to shop for either a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND: e.g., "Nordic Pure"] filter
# 7 I'd like to purchase either a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND: e.g., "Nordic Pure"] filter
# ...

# %%
like10 = [] 

for f in fil10:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            like10.append(f"{s} {f} that are either [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"], please")
        else:
            if 'air' in f:
                like10.append(f"{s} an {f} that is either [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"], please")
            else:
                like10.append(f"{s} a {f} that is either [BRAND: e.g., \"3M\"] or [BRAND: e.g., \"Nordic Pure\"], please")

# %%
for l in like10:
    print(like10.index(l), l)
# Out:
# 0 I'm looking for a filter that is either [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"], please
# 1 I need a filter that is either [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"], please
# 2 I want to invest in a filter that is either [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"], please
# 3 I need to get a filter that is either [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"], please
# 4 I need to grab a filter that is either [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"], please
# 5 someone told me to try a filter that is either [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"], please
# 6 I'm here to shop for a filter that is either [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"], please
# 7 I'd like to purchase a filter that is either [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"], please
# 8 I'm looking for an air filter that is either [BRAND: e.g., "3M"] or [BRAND: e.g., "Nordic Pure"], please
# ...

# %%
also10 = [] 

for f in fil10:
    for s in s_s5mod[:8]:
        if 'filters' in f:
            also10.append(f"{s} [BRAND: e.g., \"3M\"] {f}, but I also want to look at [BRAND: e.g., \"Nordic Pure\"] and [BRAND: e.g., \"Honeywell\"] as well.")
        else:
            also10.append(f"{s} a [BRAND: e.g., \"3M\"] {f}, but I also want to look at [BRAND: e.g., \"Nordic Pure\"] and [BRAND: e.g., \"Honeywell\"] as well.")

# %%
for a in also10:
    print(also10.index(a), a)
# Out:
# 0 I'm looking for a [BRAND: e.g., "3M"] filter, but I also want to look at [BRAND: e.g., "Nordic Pure"] and [BRAND: e.g., "Honeywell"] as well.
# 1 I need a [BRAND: e.g., "3M"] filter, but I also want to look at [BRAND: e.g., "Nordic Pure"] and [BRAND: e.g., "Honeywell"] as well.
# 2 I want to invest in a [BRAND: e.g., "3M"] filter, but I also want to look at [BRAND: e.g., "Nordic Pure"] and [BRAND: e.g., "Honeywell"] as well.
# 3 I need to get a [BRAND: e.g., "3M"] filter, but I also want to look at [BRAND: e.g., "Nordic Pure"] and [BRAND: e.g., "Honeywell"] as well.
# 4 I need to grab a [BRAND: e.g., "3M"] filter, but I also want to look at [BRAND: e.g., "Nordic Pure"] and [BRAND: e.g., "Honeywell"] as well.
# 5 someone told me to try a [BRAND: e.g., "3M"] filter, but I also want to look at [BRAND: e.g., "Nordic Pure"] and [BRAND: e.g., "Honeywell"] as well.
# ...

# %%
s_s5mod10 = s_s5mod[:]

s_s5mod10.remove(s_s5mod10[5])

# %%
for s in s_s5mod10:
    print(s_s5mod10.index(s), s)
# Out:
# 0 I'm looking for
# 1 I need
# 2 I want to invest in
# 3 I need to get
# 4 I need to grab
# 5 I'm here to shop for
# 6 I'd like to purchase
# 7 I like

# %%
know10 = [] 

for f in fil10:
    for s in s_s5mod10:
        if 'filters' in f:
            know10.append(f"I don't know what {s} yet, but it's between [BRAND: e.g., \"Nordic Pure\"] or [BRAND: e.g., \"Honeywell\"] {f}")
        else:
            know10.append(f"I don't know what {s} yet, but it's between a [BRAND: e.g., \"Nordic Pure\"] or [BRAND: e.g., \"Honeywell\"] {f}")

# %%
for k in know10:
    print(know10.index(k), k)
# Out:
# 0 I don't know what I'm looking for yet, but it's between a [BRAND: e.g., "Nordic Pure"] or [BRAND: e.g., "Honeywell"] filter
# 1 I don't know what I need yet, but it's between a [BRAND: e.g., "Nordic Pure"] or [BRAND: e.g., "Honeywell"] filter
# 2 I don't know what I want to invest in yet, but it's between a [BRAND: e.g., "Nordic Pure"] or [BRAND: e.g., "Honeywell"] filter
# 3 I don't know what I need to get yet, but it's between a [BRAND: e.g., "Nordic Pure"] or [BRAND: e.g., "Honeywell"] filter
# 4 I don't know what I need to grab yet, but it's between a [BRAND: e.g., "Nordic Pure"] or [BRAND: e.g., "Honeywell"] filter
# 5 I don't know what I'm here to shop for yet, but it's between a [BRAND: e.g., "Nordic Pure"] or [BRAND: e.g., "Honeywell"] filter
# 6 I don't know what I'd like to purchase yet, but it's between a [BRAND: e.g., "Nordic Pure"] or [BRAND: e.g., "Honeywell"] filter
# ...

# %%
list10 = []

for s in s_s10:
    for f in fb10:
        if s is s_s10[2] or s is s_s10[3] or s is s_s10[9] or s is s_s10[11]:
            list10.append(f"{s} {f}")
        else:
            list10.append(f"{s} {f}")

# %%
can10 = []

for x in list10:
    if 'Can you help me' in x:
        can10.append(f"{x[:-1]} while I'm here?")
    else:
        continue

# %%
for c in can10:
    print(can10.index(c), c)
# Out:
# 0 Can you help me with a [BRAND: e.g., "3M"] or [BRAND:e.g., "Nordic Pure"] filte while I'm here?
# 1 Can you help me with a [BRAND: e.g., "3M"] or [BRAND:e.g., "Nordic Pure"] air filte while I'm here?
# 2 Can you help me with [BRAND: e.g., "3M"] or [BRAND:e.g., "Nordic Pure"] filter while I'm here?
# 3 Can you help me with [BRAND: e.g., "3M"] or [BRAND:e.g., "Nordic Pure"] air filter while I'm here?
# 4 Can you help me with a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND:e.g., "Nordic Pure"] filte while I'm here?
# 5 Can you help me with a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND:e.g., "Nordic Pure"] air filte while I'm here?
# 6 Can you help me with [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND:e.g., "Nordic Pure"] filter while I'm here?
# 7 Can you help me with [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND:e.g., "Nordic Pure"] air filter while I'm here?
# ...

# %%
list10_2 = list10[:] + either10[:] + like10[:] + also10[:] + know10[:] + can10

# %%
for l in list10_2:
    print(list10_2.index(l), l)
# Out:
# 0 I'm looking for a [BRAND: e.g., "3M"] or [BRAND:e.g., "Nordic Pure"] filter
# 1 I'm looking for a [BRAND: e.g., "3M"] or [BRAND:e.g., "Nordic Pure"] air filter
# 2 I'm looking for [BRAND: e.g., "3M"] or [BRAND:e.g., "Nordic Pure"] filters
# 3 I'm looking for [BRAND: e.g., "3M"] or [BRAND:e.g., "Nordic Pure"] air filters
# 4 I'm looking for a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND:e.g., "Nordic Pure"] filter
# 5 I'm looking for a [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND:e.g., "Nordic Pure"] air filter
# 6 I'm looking for [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND:e.g., "Nordic Pure"] filters
# 7 I'm looking for [BRAND: e.g., "3M"], [BRAND: e.g., "Honeywell"], or [BRAND:e.g., "Nordic Pure"] air filters
# 8 I'm looking for [BRAND: e.g., "3M"] and [BRAND:e.g., "Nordic Pure"] filters
# 9 I'm looking for [BRAND: e.g., "3M"] and [BRAND:e.g., "Nordic Pure"] air filters
# ...

# %%
case10_test = open('Case10.txt', 'w')

case10_test.write('\n'.join(sorted(list(set(list10_2)))))

case10_test.close()
